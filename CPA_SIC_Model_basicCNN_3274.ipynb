# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.utils import shuffle
from datetime import timedelta
import time
import math
import sys
import cv2
import os
import random
import glob

# %%
tf.__version__
# Out:
# '1.2.1'

# %%
sys.version
# Out:
# '3.6.0 |Anaconda 4.3.0 (64-bit)| (default, Dec 23 2016, 11:57:41) [MSC v.1900 64 bit (AMD64)]'

# %%
# Convolutional Layer 1.
filter_size1 = 5          # Convolution filters are 5 x 5 pixels.
num_filters1 = 32         # There are 32 of these filters.

# Convolutional Layer 2.
filter_size2 = 3          # Convolution filters are 3 x 3 pixels.
num_filters2 = 16         # There are 16 of these filters.

# Convolutional Layer 3.
filter_size3 = 3          # Convolution filters are 3 x 3 pixels.
num_filters3 = 16         # There are 16 of these filters.

# Fully-connected layer.
fc_size_1 = 512             # Number of neurons in fully-connected layer.

fc_size_2 = 128             # Number of neurons in fully-connected layer.

# %%
# Number of colour channels for the images: 4 channel for RGB and Transparent .
num_channels = 4

# We know that Satellite images are 640 pixels in each dimension.
img_size = 640

# Images are stored in one-dimensional arrays of this length.
img_size_flat = img_size * img_size * num_channels

# Tuple with height and width of images used to reshape arrays.
img_shape = (img_size, img_size)
img_shape_wChnls = (img_size, img_size, num_channels)

# class info
classes = ['vegetation', 'notVegetation']
# Number of classes, one class for each of 2 digits like Green and NotGreen.
num_classes = len(classes)

dropout_rate = 0.25

# %%
num_classes
# Out:
# 2

# %% [markdown]
# # Pre-processing Data

# %% [markdown]
# ## Convert Images to Array and group by dataset

# %% [markdown]
# identify feature of images , labels etc.

# %%
class DataSet(object):

    def __init__(self, images, labels, ids, cls):
        """Construct a DataSet. one_hot arg is used only if fake_data is true."""

        self._num_examples = images.shape[0]


        # Convert shape from [num examples, rows, columns, depth]
        # to [num examples, rows*columns] (assuming depth == 1)
        # Convert from [0, 255] -> [0.0, 1.0].

        images = images.astype(np.float32)
        images = np.multiply(images, 1.0 / 255.0)

        self._images = images
        self._labels = labels
        self._ids = ids
        self._cls = cls
        self._epochs_completed = 0
        self._index_in_epoch = 0

    @property
    def images(self):
        return self._images

    @property
    def labels(self):
        return self._labels

    @property
    def ids(self):
        return self._ids

    @property
    def cls(self):
        return self._cls

    @property
    def num_examples(self):
        return self._num_examples

    @property
    def epochs_completed(self):
        return self._epochs_completed

    def next_batch(self, batch_size):
        start = self._index_in_epoch
        self._index_in_epoch += batch_size

        if self._index_in_epoch > self._num_examples:

            self._epochs_completed += 1

            start = 0
            self._index_in_epoch = batch_size
            assert batch_size <= self._num_examples
        end = self._index_in_epoch

        return self._images[start:end], self._labels[start:end], self._ids[start:end], self._cls[start:end]

# %% [markdown]
# load images from path directory

# %%
def load_and_split_data(train_path, image_size, classes):
    images = []
    labels = []
    ids = []
    cls = []

    print('Reading training images')
    for fld in classes:   # assuming data directory has a separate folder for each class, and that each folder is named after the class
        index = classes.index(fld)
        print('Loading {} files (Index: {})'.format(fld, index))
        path = os.path.join(train_path, fld, '*g')
        files = glob.glob(path)
        for fl in files:
            #image = cv2.imread(fl)                         # 3-channal
            image = cv2.imread(fl, cv2.IMREAD_UNCHANGED)    # 4-channal
            image = cv2.resize(image, (image_size, image_size), cv2.INTER_LINEAR)
            image = image.reshape(img_size_flat)
            images.append(image)
            label = np.zeros(len(classes))
            label[index] = 1.0
            labels.append(label)
            flbase = os.path.basename(fl)
            ids.append(flbase)
            cls.append(fld)
    images = np.array(images)
    labels = np.array(labels)
    ids = np.array(ids)
    cls = np.array(cls)

    return images, labels, ids, cls

# %% [markdown]
# read image and split to train , validate and test set

# %%
def read_train_sets(train_path, image_size, classes, validation_size=0):
    class DataSets(object):
        pass
    data_sets = DataSets()

    images, labels, ids, cls = load_and_split_data(train_path, image_size, classes)
    
    index_vegetation, = np.where(cls == classes[0] )
    index_notvegetation, = np.where(cls == classes[1] )
    
    if isinstance(validation_size, float):
        validation_size = int(validation_size * images.shape[0])
        
    balance_size = int( (len(images) - validation_size) / num_classes )
    index_random_vegetation = random.sample(list(index_vegetation), balance_size)
    index_random_notVegetation = random.sample(list(index_notvegetation), balance_size)
    index_random_balance = index_random_vegetation + index_random_notVegetation
    
    train_images = images[index_random_balance]
    train_labels  = labels[index_random_balance]
    train_ids  = ids[index_random_balance]
    train_cls  = cls[index_random_balance]
    
    validation_cls = np.delete(cls, index_random_balance)
    validation_ids = np.delete(ids, index_random_balance)
    validation_labels = np.delete(labels, index_random_balance, axis=0)
    validation_images = np.delete(images, index_random_balance, axis=0)   
    
    train_images, train_labels, train_ids, train_cls = shuffle(train_images, 
                                                               train_labels, 
                                                               train_ids, 
                                                               train_cls)  # shuffle the data
    validation_images, validation_labels, validation_ids, validation_cls = shuffle(validation_images, 
                                                                                   validation_labels, 
                                                                                   validation_ids, 
                                                                                   validation_cls)  # shuffle the data

    data_sets.train = DataSet(train_images, train_labels, train_ids, train_cls)
    data_sets.valid = DataSet(validation_images, validation_labels, validation_ids, validation_cls)

    return data_sets

def read_test_set(test_path, image_size, classes):
    class DataSets(object):
        pass
    datatest = DataSets()
    
    test_images, test_labels , test_ids , test_cls  = load_and_split_data(test_path, image_size, classes)
    
    datatest = DataSet(test_images, test_labels, test_ids, test_cls)
    
    return datatest

# %% [markdown]
# ## Load Image and convert to Array

# %%
# validation split
validation_size = .30

train_path = 'D:\FaamruProject_kor\Dataset\FaamruDS\_training'
test_path = 'D:\FaamruProject_kor\Dataset\FaamruDS\_testing'

# %%
data = read_train_sets(train_path, img_size, classes, validation_size=validation_size)
# Out:
# Reading training images
# Loading vegetation files (Index: 0)
# Loading notVegetation files (Index: 1)

# %%
datatest = read_test_set(test_path, img_size, classes)
# Out:
# Reading training images
# Loading vegetation files (Index: 0)
# Loading notVegetation files (Index: 1)

# %%
print("Size of Dataset :")
print("- Training-set\t\t: {}".format(len(data.train.labels)))
print("- Validation-set\t: {}".format(len(data.valid.labels)))
print("- Test-set(Unseen Data)\t: {}".format(len(datatest.images)))
# Out:
# Size of Dataset :
# - Training-set		: 1834
# - Validation-set	: 785
# - Test-set(Unseen Data)	: 655

# %%
data.train.images.shape
# Out:
# (1834, 1638400)

# %%
len(data.train.images[5])
# Out:
# 1638400

# %%
len(datatest.images[5])
# Out:
# 1638400

# %%
images = data.train.images
print('images[1]\t\t: ',images[1])
print('type of images[1]\t: ',type(images[1]))
print('shape of images[1]\t: ',images.shape)
print('len of images[1]\t: ',len(images[1]))
# Out:
# images[1]		:  [ 1.  1.  1. ...,  1.  1.  0.]
# type of images[1]	:  <class 'numpy.ndarray'>
# shape of images[1]	:  (1834, 1638400)
# len of images[1]	:  1638400

# %%
data.train.cls
# Out:
# array(['vegetation', 'vegetation', 'vegetation', ..., 'vegetation',
#        'vegetation', 'notVegetation'],
#       dtype='<U13')

# %%
vegetationT = sum(i == 'vegetation' for i in data.train.cls)
NotvegetationT = sum(i == 'notVegetation' for i in data.train.cls)
vegetationV = sum(i == 'vegetation' for i in data.valid.cls)
NotvegetationV = sum(i == 'notVegetation' for i in data.valid.cls)

# %%
print('train -> vegetation : ',vegetationT)
print('train -> notVegetation : ',NotvegetationT)
print('validate -> vegetation : ',vegetationV)
print('validate -> notVegetation : ',NotvegetationV)
# Out:
# train -> vegetation :  917
# train -> notVegetation :  917
# validate -> vegetation :  255
# validate -> notVegetation :  530

# %% [markdown]
# # Plotting Images

# %%
def index_random(data ,size):
    data_range = range(len(data))
    
    return random.sample(data_range, size)

# %%
### Plotting image by array data
def plot_img_new(images, cls_true , ids , cls_pred=None):  
    
    #features = data_arr[0]            # images
    #lables = data_arr[1]              # cls_true
    #images_filename = data_arr[2]     # ids 
    
    
    
    if len(images) <16 :
        indexs_random = range(len(images))
    else :
        indexs_random = index_random(images, 16)
        assert len(indexs_random) == 16
        
    fig, axes = plt.subplots(4, 4 ,figsize=(12,12))
    fig.subplots_adjust(hspace=0.3, wspace=0.1)
    
    for i, ax in enumerate(axes.flat):
                
        # Read PNG Image from Directory 
        feature_img = images[ indexs_random[i] ]
        
        # Plot image.
        ax.imshow(cv2.cvtColor(feature_img.reshape(img_shape_wChnls), cv2.COLOR_BGR2RGB), interpolation = 'bicubic' )
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])  # to hide tick values on X and Y axis
        
        # Show the Title of images.
        ax.set_title('Pic : {0}'.format( ids[indexs_random[i]] ))
        
        #Show True and Predicted classes
        if cls_pred is None:
            xlabel = 'True : {0}'.format( cls_true[indexs_random[i]] )
        else:
            xlabel = 'True : {0}, \nPred : {1}'.format( cls_true[indexs_random[i]] , cls_pred[i])
        
        ax.set_xlabel(xlabel)
        
        
        
    plt.show()

# %%
print('')
print('\t\t*** Training Data : Sampling 16 images of {} images *** '.format(len(data.train.images)))

# Get the first images from the trainning-set.
images_train = data.train.images

# Get the true classes for those images.
cls_true_train = data.train.cls

# Get the file names for those images.
ids_filename_train = data.train.ids

# Plot the images and labels using our helper-function above.
plot_img_new(images=images_train, cls_true=cls_true_train , ids=ids_filename_train)
# Out:
# 		*** Training Data : Sampling 16 images of 1834 images ***

# %%
print('')
print('\t\t*** Validation Data : Sampling 16 images of {} images *** '.format(len(data.valid.images)))

# Get the first images from the validate-set.
images_validate = data.valid.images

# Get the true classes for those images.
cls_true_validate = data.valid.cls

# Get the file names for those images.
ids_filename_validate = data.valid.ids

plot_img_new(images=images_validate, cls_true=cls_true_validate , ids=ids_filename_validate)
# Out:
# 		*** Validation Data : Sampling 16 images of 785 images ***

# %% [markdown]
# # TensorFlow Graph

# %% [markdown]
# create component in model by my designing

# %% [markdown]
# # Creating New Variables

# %%
def new_weights(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.05))

# %%
def new_biases(length):
    return tf.Variable(tf.constant(0.05, shape=[length]))

# %% [markdown]
# # Creating a Convolutional Layer

# %%
def conv_layer(input,         # The previous layer.
                   num_input_channels, # Num. channels in prev. layer.
                   filter_size,        # Width and height of each filter.
                   num_filters,        # Number of filters.
                   use_pooling=True):  # Use 2x2 max-pooling.

    # Shape of the filter-weights for the convolution.
    shape = [filter_size, filter_size, num_input_channels, num_filters]

    # Create new weights aka. filters with the given shape.
    weights = new_weights(shape=shape)

    # Create new biases, one for each filter.
    biases = new_biases(length=num_filters)

    # Create the TensorFlow operation for convolution.
    layer = tf.nn.conv2d(input=input,
                         filter=weights,
                         strides=[1, 1, 1, 1],
                         padding='SAME')

    # Add the biases to the results of the convolution.
    layer += biases

    # Use pooling to down-sample the image resolution?
    if use_pooling:
        layer = tf.nn.max_pool(value=layer,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME')

    # Rectified Linear Unit (ReLU).
    layer = tf.nn.relu(layer)

    return layer, weights

# %% [markdown]
# # Creating a Full-Connected Layer

# %%
def flatten_layer(layer):
    # Get the shape of the input layer.
    layer_shape = layer.get_shape()

    num_features = layer_shape[1:4].num_elements()
    
    layer_flat = tf.reshape(layer, [-1, num_features])

    return layer_flat, num_features

# %%
def dropout_layer(input,dropout_rate,traning_mode):
    features = input
    dropout_layer = tf.layers.dropout(features,rate=dropout_rate,training=traning_mode)
    
    return dropout_layer

# %%
def fc_layer(input,          # The previous layer.
                 num_inputs,     # Num. inputs from prev. layer.
                 num_outputs,    # Num. outputs.
                 use_relu=True): # Use Rectified Linear Unit (ReLU)?

    # Create new weights and biases.
    weights = new_weights(shape=[num_inputs, num_outputs])
    biases = new_biases(length=num_outputs)

    # Calculate the layer as the matrix multiplication of
    layer = tf.matmul(input, weights) + biases

    # Use ReLU?
    if use_relu:
        layer = tf.nn.relu(layer)

    return layer

# %% [markdown]
# ### Placeholder variables

# %%
x = tf.placeholder(tf.float32, shape=[None, img_size_flat], name='x') #img_size_flat 640 x 640

# %%
x_image = tf.reshape(x, [-1, img_size, img_size, num_channels])

# %%
y_true = tf.placeholder(tf.float32, shape=[None, num_classes], name='y_true')

# %%
y_true_cls = tf.argmax(y_true, axis=1)

# %% [markdown]
# ### Convolutional Layer 1

# %%
layer_conv1, weights_conv1 = conv_layer(input=x_image,  #image_dataset
                   num_input_channels=num_channels,     #number_channal=4
                   filter_size=filter_size1,            #filter_size = 5 x 5
                   num_filters=num_filters1,            #number_filter = 32
                   use_pooling=True)                    #max_pooling = 2x2 , stride = 2 step

# %%
layer_conv1
# Out:
# <tf.Tensor 'Relu:0' shape=(?, 320, 320, 32) dtype=float32>

# %% [markdown]
# ### Convolutional Layer 2

# %%
layer_conv2, weights_conv2 = conv_layer(input=layer_conv1,  #image_dataset
                   num_input_channels=num_filters1,         #number_channal is num_filter 0f conv. layer 1 = 32 
                   filter_size=filter_size2,                #filter_size = 3 x 3
                   num_filters=num_filters2,                #number_filter = 16
                   use_pooling=True)                        #max_pooling = 2x2 , stride = 2 step

# %%
layer_conv2
# Out:
# <tf.Tensor 'Relu_1:0' shape=(?, 160, 160, 16) dtype=float32>

# %% [markdown]
# ### Convolutional Layer 3

# %%
layer_conv3, weights_conv3 = conv_layer(input=layer_conv2,  #image_dataset
                   num_input_channels=num_filters2,         #number_channal is num_filter 0f conv. layer 1 = 32 
                   filter_size=filter_size3,                #filter_size = 3 x 3
                   num_filters=num_filters3,                #number_filter = 16
                   use_pooling=True)                        #max_pooling = 2x2 , stride = 2 step

# %%
layer_conv3
# Out:
# <tf.Tensor 'Relu_2:0' shape=(?, 80, 80, 16) dtype=float32>

# %% [markdown]
# ### Flatten Layer 1

# %%
layer_flat, num_features = flatten_layer(layer_conv3)

# %%
layer_flat
# Out:
# <tf.Tensor 'Reshape_1:0' shape=(?, 102400) dtype=float32>

# %%
num_features
# Out:
# 102400

# %% [markdown]
# ### Full-Connected Layer 1

# %%
layer_fc1 = fc_layer(input=layer_flat,
                         num_inputs=num_features,
                         num_outputs=fc_size_1,          #fc_size =  512
                         use_relu=True)

# %%
layer_fc1
# Out:
# <tf.Tensor 'Relu_3:0' shape=(?, 512) dtype=float32>

# %% [markdown]
# ### Dropout Layer 1

# %%
layer_dropout1 = dropout_layer(input=layer_fc1,
                         dropout_rate=dropout_rate,
                         traning_mode=True)

# %%
layer_dropout1
# Out:
# <tf.Tensor 'dropout/dropout/mul:0' shape=(?, 512) dtype=float32>

# %% [markdown]
# ### Full-Connected Layer 2

# %%
layer_fc2 = fc_layer(input=layer_dropout1,
                         num_inputs=fc_size_1,
                         num_outputs=fc_size_2,          #fc_size = 128 
                         use_relu=True)

# %%
layer_fc2
# Out:
# <tf.Tensor 'Relu_4:0' shape=(?, 128) dtype=float32>

# %% [markdown]
# ### Dropout Layer 2

# %%
layer_dropout2 = dropout_layer(input=layer_fc2,
                         dropout_rate=dropout_rate,
                         traning_mode=True)

# %%
layer_dropout2
# Out:
# <tf.Tensor 'dropout_2/dropout/mul:0' shape=(?, 128) dtype=float32>

# %% [markdown]
# ### Full-Connected Layer 3

# %%
layer_fc3 = fc_layer(input=layer_dropout2,
                         num_inputs=fc_size_2,
                         num_outputs=num_classes,          #fc_size = 2 class _ output
                         use_relu=False)

# %%
layer_fc3
# Out:
# <tf.Tensor 'add_5:0' shape=(?, 2) dtype=float32>

# %% [markdown]
# # Predicted Class

# %% [markdown]
# Generate Predictions

# %%
y_pred = tf.nn.softmax(layer_fc3)  #probabilities

# %%
y_pred_cls = tf.argmax(y_pred, axis=1)    #classes

# %% [markdown]
# # Cost-function to be optimized

# %%
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=layer_fc3,
                                                        labels=y_true)

# %%
cost = tf.reduce_mean(cross_entropy)

# %% [markdown]
# # Optimization Method

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(cost) #'learning_rate': 0.0001

# %% [markdown]
# # Performance Measures

# %% [markdown]
# this section is create values to confusion matrix

# %%
correct_prediction = tf.equal(y_pred_cls, y_true_cls)

# %%
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %% [markdown]
# ### Saver

# %%
saver = tf.train.Saver()

# %%
save_dir = 'D:\FaamruProject_kor\Model\checkpoints\_3274'

# %%
date_create = "{}".format(time.strftime('%Y%m%d', time.localtime(time.time())))

# %%
save_dir_date = os.path.join(save_dir, date_create)
if not os.path.exists(save_dir_date):
    os.makedirs(save_dir_date)

# %%
name_directory_best_validation = 'best_validate_3274_basicCNN'

# %%
name_directory_best_validation
# Out:
# 'best_validate_3274_basicCNN'

# %%
save_path = os.path.join(save_dir_date, name_directory_best_validation)

# %%
save_path
# Out:
# 'D:\\FaamruProject_kor\\Model\\checkpoints\\_3274\\20180503\\best_validate_3274_basicCNN'

# %% [markdown]
# # TensorFlow Run

# %%
#Create TensorFlow session

session = tf.Session()

#Initialize variables

session.run(tf.global_variables_initializer())

# %% [markdown]
# function to perform optimization iterations

# %%
train_batch_size = 128

# %%
validate_batch_size = 64

# %%
# Best validation accuracy seen so far.
best_validation_loss = 1.5

# Iteration-number for last improvement to validation accuracy.
last_improvement = 0

# Stop optimization if no improvement found in this many iterations.
require_improvement = 5000

# %%
def print_progress(optimize_iterations, epoch, feed_dict_train, feed_dict_validate, val_loss , improved_str):
    # Calculate the accuracy on the training-set.
    acc = session.run(accuracy, feed_dict=feed_dict_train)
    val_acc = session.run(accuracy, feed_dict=feed_dict_validate)
    msg = "Optimize_iterations : {0}\tEpoch {1} --- Training Accuracy: {2:>6.3%}, Validation Accuracy: {3:>6.3%}, Validation Loss: {4:.3f} {5}"
    print(msg.format(optimize_iterations,epoch, acc, val_acc, val_loss , improved_str))

# %%
# Counter for total number of iterations performed so far.
total_iterations = 0

def train_optimize(num_iterations , continue_iterate=False):
    # Ensure we update the global variable rather than a local copy.
    global total_iterations
    global best_validation_loss         #20180329
    global last_improvement             #20180329
    global patience
    global require_improvement
    
    number_batch_epoch = 0

    # Start-time used for printing time-usage below.
    start_time = time.time()
    print("Start Time : " + time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())))  

    for i in range(total_iterations,
                   total_iterations + num_iterations):

        # Get a batch of training examples.
        x_batch, y_true_batch, _, cls_batch = data.train.next_batch(train_batch_size)
        x_valid_batch, y_valid_batch, _, valid_cls_batch = data.valid.next_batch(validate_batch_size)

        # Put the batch into a dict with the proper names
        feed_dict_train = {x: x_batch,
                           y_true: y_true_batch}
        
        feed_dict_validate = {x: x_valid_batch,
                              y_true: y_valid_batch}

        # Run the optimizer using this batch of training data.
        session.run(optimizer, feed_dict=feed_dict_train)
        

        # Print status at end of each epoch (defined as full pass through training dataset).
        
        #if i % int(data.train.num_examples/train_batch_size) == 0: 
        val_loss = session.run(cost, feed_dict=feed_dict_validate)
        if number_batch_epoch < int(data.train.num_examples/train_batch_size):
                number_batch_epoch += 1
        else:
                number_batch_epoch = 0
        optimize_iterations = i+1

        if require_improvement:    
            if val_loss < best_validation_loss:
                best_validation_loss = val_loss
                last_improvement = 0
                saver.save(sess=session, save_path=save_path)
                improved_str = '*'
            else:
                last_improvement += 1
                improved_str = ''

            if last_improvement == require_improvement:
                break
        
        print_progress(optimize_iterations,number_batch_epoch, feed_dict_train, feed_dict_validate, val_loss , improved_str)

    # Update the total number of iterations performed.
    if continue_iterate:
        total_iterations += num_iterations

    # Ending time.
    end_time = time.time()
    print("End Time : " + time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(end_time)))

    # Difference between start and end-times.
    time_dif = end_time - start_time

    # Print the time-usage.
    print("Time elapsed: " + str(timedelta(seconds=int(round(time_dif)))))

# %% [markdown]
# function to plot example errors

# %%
def plot_example_errors(cls_pred, correct):

    # Negate the boolean array.
    incorrect = (correct == False)
    
    # Get the images from the test-set that have been
    # incorrectly classified.
    images = data.valid.images[incorrect]
    ids = data.valid.ids[incorrect]
    
    # Get the predicted classes for those images.
    cls_pred = cls_pred[incorrect]

    # Get the true classes for those images.
    cls_true = data.valid.cls[incorrect]
    
       
    plot_errors_image(images=images,
                cls_true=cls_true,
                ids=ids,
                cls_pred=cls_pred)

# %%
def plot_errors_image(images , cls_true , ids , cls_pred):
      
    # Number of filters used in the conv. layer.
    num_filters = images.shape[0]

    # Number of grids to plot.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids,figsize=(15,15))
    fig.subplots_adjust(hspace=0.8, wspace=0.2)

    # Plot the output images of all the filters.
    for i, ax in enumerate(axes.flat):
        if i<num_filters:
            # Get the output image of using the i'th filter.
            img = images[i]

            # Plot image.
            ax.imshow(cv2.cvtColor(img.reshape(img_shape_wChnls), cv2.COLOR_BGR2RGB), interpolation = 'bicubic' )
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
        
        xlabel = '{0} \nTrue : {1} \nPred : {2}'.format(ids[i] , cls_true[i] , cls_pred[i])
        ax.set_xlabel(xlabel)
        
        if i == num_filters-1 :
            break
            
            
    plt.xticks([])
    plt.yticks([])

    plt.show()

# %% [markdown]
# function to plot confusion matrix

# %%
def plot_confusion_matrix(cls_pred):
    # cls_pred is an array of the predicted class-number for all images in the test-set.

    # Get the true classifications for the test-set.
    cls_true = data.valid.cls
    
    # Get the confusion matrix using sklearn.
    cm = confusion_matrix(y_true=cls_true,
                          y_pred=cls_pred)

    # Print the confusion matrix as text.
    print(cm)

    # Plot the confusion matrix as an image.
    plt.matshow(cm)
    
    # Print the Recall - Precision - F1 score.
    #print('Recall : ',metrics.recall_score( cls_true , cls_pred ))
    
    

    # Make various adjustments to the plot.
    plt.colorbar()
    tick_marks = np.arange(num_classes)
    plt.xticks(tick_marks, range(num_classes))
    plt.yticks(tick_marks, range(num_classes))
    plt.xlabel('Predicted')
    plt.ylabel('True')

    plt.show()

# %% [markdown]
# function for showing the performance

# %%
def validation_performance(show_example_errors=False,
                        show_confusion_matrix=False):

    # Number of images in the test-set.
    num_test = len(data.valid.images)

    cls_pred = np.zeros(shape=num_test, dtype=np.int)


    i = 0

    while i < num_test:
        # The ending index for the next batch is denoted j.
        j = min(i + validate_batch_size, num_test)

        # Get the images from the test-set between index i and j.
        images = data.valid.images[i:j, :]
        

        # Get the associated labels.
        labels = data.valid.labels[i:j, :]

        # Create a feed-dict with these images and labels.
        feed_dict = {x: images,
                     y_true: labels}

        # Calculate the predicted class using TensorFlow.
        cls_pred[i:j] = session.run(y_pred_cls, feed_dict=feed_dict)

        # Set the start-index for the next batch to the
        # end-index of the current batch.
        i = j

    cls_true = np.array(data.valid.cls)
    cls_pred = np.array([classes[x] for x in cls_pred]) 

    # Create a boolean array whether each image is correctly classified.
    correct = (cls_true == cls_pred)

    # Calculate the number of correctly classified images.
    correct_sum = correct.sum()

    acc = float(correct_sum) / num_test

    # Print the accuracy.
    msg = "Accuracy on Validate-Set: {0:.3%} ({1} / {2})"
    print(msg.format(acc, correct_sum, num_test))

    # Plot some examples of mis-classifications, if desired.
    if show_example_errors:
        print("Example errors:")
        plot_example_errors(cls_pred=cls_pred, correct=correct)

    # Plot the confusion matrix, if desired.
    if show_confusion_matrix:
        print("Confusion Matrix:")
        plot_confusion_matrix(cls_pred=cls_pred)

# %% [markdown]
# ## Performance after 1 optimization iteration

# %%
train_optimize(num_iterations=1)
# Out:
# Start Time : 2018-05-03 14:49:59
# Optimize_iterations : 1	Epoch 1 --- Training Accuracy: 60.156%, Validation Accuracy: 45.312%, Validation Loss: 0.719 *
# End Time : 2018-05-03 14:52:46
# Time elapsed: 0:02:47

# %%
validation_performance()
# Out:
# Accuracy on Validate-Set: 50.955% (400 / 785)

# %% [markdown]
# ## Performance after 100 optimization iterations
#
# After 100 optimization iterations, the model should have significantly improved its classification accuracy.

# %%
train_optimize(num_iterations=100)
# Out:
# Start Time : 2018-05-03 15:08:23
# Optimize_iterations : 1	Epoch 1 --- Training Accuracy: 53.906%, Validation Accuracy: 62.500%, Validation Loss: 0.644 *
# Optimize_iterations : 2	Epoch 2 --- Training Accuracy: 51.562%, Validation Accuracy: 46.875%, Validation Loss: 0.703
# Optimize_iterations : 3	Epoch 3 --- Training Accuracy: 54.688%, Validation Accuracy: 29.688%, Validation Loss: 0.829
# Optimize_iterations : 4	Epoch 4 --- Training Accuracy: 54.688%, Validation Accuracy: 42.188%, Validation Loss: 0.808
# Optimize_iterations : 5	Epoch 5 --- Training Accuracy: 53.906%, Validation Accuracy: 54.688%, Validation Loss: 0.703
# Optimize_iterations : 6	Epoch 6 --- Training Accuracy: 58.594%, Validation Accuracy: 59.375%, Validation Loss: 0.647
# Optimize_iterations : 7	Epoch 7 --- Training Accuracy: 53.125%, Validation Accuracy: 68.750%, Validation Loss: 0.624 *
# Optimize_iterations : 8	Epoch 8 --- Training Accuracy: 59.375%, Validation Accuracy: 73.438%, Validation Loss: 0.625
# Optimize_iterations : 9	Epoch 9 --- Training Accuracy: 61.719%, Validation Accuracy: 60.938%, Validation Loss: 0.640
# Optimize_iterations : 10	Epoch 10 --- Training Accuracy: 69.531%, Validation Accuracy: 56.250%, Validation Loss: 0.652
# Optimize_iterations : 11	Epoch 11 --- Training Accuracy: 64.844%, Validation Accuracy: 64.062%, Validation Loss: 0.635
# Optimize_iterations : 12	Epoch 12 --- Training Accuracy: 66.406%, Validation Accuracy: 64.062%, Validation Loss: 0.678
# Optimize_iterations : 13	Epoch 13 --- Training Accuracy: 61.719%, Validation Accuracy: 67.188%, Validation Loss: 0.624
# Optimize_iterations : 14	Epoch 14 --- Training Accuracy: 60.156%, Validation Accuracy: 68.750%, Validation Loss: 0.574 *
# Optimize_iterations : 15	Epoch 0 --- Training Accuracy: 64.062%, Validation Accuracy: 75.000%, Validation Loss: 0.591
# Optimize_iterations : 16	Epoch 1 --- Training Accuracy: 64.062%, Validation Accuracy: 60.938%, Validation Loss: 0.655
# Optimize_iterations : 17	Epoch 2 --- Training Accuracy: 68.750%, Validation Accuracy: 70.312%, Validation Loss: 0.676
# Optimize_iterations : 18	Epoch 3 --- Training Accuracy: 60.938%, Validation Accuracy: 57.812%, Validation Loss: 0.724
# Optimize_iterations : 19	Epoch 4 --- Training Accuracy: 65.625%, Validation Accuracy: 68.750%, Validation Loss: 0.682
# Optimize_iterations : 20	Epoch 5 --- Training Accuracy: 60.156%, Validation Accuracy: 76.562%, Validation Loss: 0.667
# Optimize_iterations : 21	Epoch 6 --- Training Accuracy: 65.625%, Validation Accuracy: 68.750%, Validation Loss: 0.607
# Optimize_iterations : 22	Epoch 7 --- Training Accuracy: 70.312%, Validation Accuracy: 70.312%, Validation Loss: 0.592
# Optimize_iterations : 23	Epoch 8 --- Training Accuracy: 67.969%, Validation Accuracy: 70.312%, Validation Loss: 0.532 *
# Optimize_iterations : 24	Epoch 9 --- Training Accuracy: 72.656%, Validation Accuracy: 64.062%, Validation Loss: 0.594
# Optimize_iterations : 25	Epoch 10 --- Training Accuracy: 71.094%, Validation Accuracy: 75.000%, Validation Loss: 0.566
# Optimize_iterations : 26	Epoch 11 --- Training Accuracy: 67.969%, Validation Accuracy: 75.000%, Validation Loss: 0.536
# Optimize_iterations : 27	Epoch 12 --- Training Accuracy: 67.188%, Validation Accuracy: 65.625%, Validation Loss: 0.595
# Optimize_iterations : 28	Epoch 13 --- Training Accuracy: 66.406%, Validation Accuracy: 60.938%, Validation Loss: 0.749
# Optimize_iterations : 29	Epoch 14 --- Training Accuracy: 70.312%, Validation Accuracy: 70.312%, Validation Loss: 0.682
# Optimize_iterations : 30	Epoch 0 --- Training Accuracy: 64.062%, Validation Accuracy: 51.562%, Validation Loss: 0.687
# Optimize_iterations : 31	Epoch 1 --- Training Accuracy: 72.656%, Validation Accuracy: 75.000%, Validation Loss: 0.605
# Optimize_iterations : 32	Epoch 2 --- Training Accuracy: 66.406%, Validation Accuracy: 75.000%, Validation Loss: 0.567
# Optimize_iterations : 33	Epoch 3 --- Training Accuracy: 66.406%, Validation Accuracy: 70.312%, Validation Loss: 0.567
# Optimize_iterations : 34	Epoch 4 --- Training Accuracy: 64.062%, Validation Accuracy: 76.562%, Validation Loss: 0.533
# Optimize_iterations : 35	Epoch 5 --- Training Accuracy: 69.531%, Validation Accuracy: 76.562%, Validation Loss: 0.528 *
# Optimize_iterations : 36	Epoch 6 --- Training Accuracy: 68.750%, Validation Accuracy: 68.750%, Validation Loss: 0.569
# Optimize_iterations : 37	Epoch 7 --- Training Accuracy: 76.562%, Validation Accuracy: 79.688%, Validation Loss: 0.544
# Optimize_iterations : 38	Epoch 8 --- Training Accuracy: 75.000%, Validation Accuracy: 78.125%, Validation Loss: 0.453 *
# Optimize_iterations : 39	Epoch 9 --- Training Accuracy: 76.562%, Validation Accuracy: 71.875%, Validation Loss: 0.538
# Optimize_iterations : 40	Epoch 10 --- Training Accuracy: 71.875%, Validation Accuracy: 62.500%, Validation Loss: 0.673
# Optimize_iterations : 41	Epoch 11 --- Training Accuracy: 73.438%, Validation Accuracy: 73.438%, Validation Loss: 0.609
# Optimize_iterations : 42	Epoch 12 --- Training Accuracy: 75.000%, Validation Accuracy: 57.812%, Validation Loss: 0.674
# Optimize_iterations : 43	Epoch 13 --- Training Accuracy: 71.875%, Validation Accuracy: 75.000%, Validation Loss: 0.595
# Optimize_iterations : 44	Epoch 14 --- Training Accuracy: 72.656%, Validation Accuracy: 78.125%, Validation Loss: 0.522
# Optimize_iterations : 45	Epoch 0 --- Training Accuracy: 74.219%, Validation Accuracy: 82.812%, Validation Loss: 0.519
# Optimize_iterations : 46	Epoch 1 --- Training Accuracy: 71.875%, Validation Accuracy: 76.562%, Validation Loss: 0.554
# Optimize_iterations : 47	Epoch 2 --- Training Accuracy: 71.094%, Validation Accuracy: 75.000%, Validation Loss: 0.565
# Optimize_iterations : 48	Epoch 3 --- Training Accuracy: 69.531%, Validation Accuracy: 71.875%, Validation Loss: 0.543
# Optimize_iterations : 49	Epoch 4 --- Training Accuracy: 69.531%, Validation Accuracy: 78.125%, Validation Loss: 0.515
# Optimize_iterations : 50	Epoch 5 --- Training Accuracy: 75.000%, Validation Accuracy: 82.812%, Validation Loss: 0.442 *
# Optimize_iterations : 51	Epoch 6 --- Training Accuracy: 79.688%, Validation Accuracy: 76.562%, Validation Loss: 0.545
# Optimize_iterations : 52	Epoch 7 --- Training Accuracy: 82.812%, Validation Accuracy: 68.750%, Validation Loss: 0.609
# Optimize_iterations : 53	Epoch 8 --- Training Accuracy: 80.469%, Validation Accuracy: 78.125%, Validation Loss: 0.476
# Optimize_iterations : 54	Epoch 9 --- Training Accuracy: 82.031%, Validation Accuracy: 71.875%, Validation Loss: 0.604
# Optimize_iterations : 55	Epoch 10 --- Training Accuracy: 78.125%, Validation Accuracy: 71.875%, Validation Loss: 0.579
# Optimize_iterations : 56	Epoch 11 --- Training Accuracy: 74.219%, Validation Accuracy: 79.688%, Validation Loss: 0.585
# Optimize_iterations : 57	Epoch 12 --- Training Accuracy: 75.781%, Validation Accuracy: 81.250%, Validation Loss: 0.470
# Optimize_iterations : 58	Epoch 13 --- Training Accuracy: 75.781%, Validation Accuracy: 82.812%, Validation Loss: 0.462
# Optimize_iterations : 59	Epoch 14 --- Training Accuracy: 73.438%, Validation Accuracy: 81.250%, Validation Loss: 0.478
# Optimize_iterations : 60	Epoch 0 --- Training Accuracy: 73.438%, Validation Accuracy: 75.000%, Validation Loss: 0.524
# Optimize_iterations : 61	Epoch 1 --- Training Accuracy: 78.125%, Validation Accuracy: 71.875%, Validation Loss: 0.508
# Optimize_iterations : 62	Epoch 2 --- Training Accuracy: 72.656%, Validation Accuracy: 87.500%, Validation Loss: 0.448
# Optimize_iterations : 63	Epoch 3 --- Training Accuracy: 79.688%, Validation Accuracy: 73.438%, Validation Loss: 0.547
# Optimize_iterations : 64	Epoch 4 --- Training Accuracy: 80.469%, Validation Accuracy: 75.000%, Validation Loss: 0.641
# Optimize_iterations : 65	Epoch 5 --- Training Accuracy: 77.344%, Validation Accuracy: 81.250%, Validation Loss: 0.444
# Optimize_iterations : 66	Epoch 6 --- Training Accuracy: 85.156%, Validation Accuracy: 76.562%, Validation Loss: 0.558
# Optimize_iterations : 67	Epoch 7 --- Training Accuracy: 85.156%, Validation Accuracy: 81.250%, Validation Loss: 0.472
# Optimize_iterations : 68	Epoch 8 --- Training Accuracy: 83.594%, Validation Accuracy: 82.812%, Validation Loss: 0.427 *
# Optimize_iterations : 69	Epoch 9 --- Training Accuracy: 85.156%, Validation Accuracy: 78.125%, Validation Loss: 0.459
# Optimize_iterations : 70	Epoch 10 --- Training Accuracy: 78.125%, Validation Accuracy: 81.250%, Validation Loss: 0.490
# Optimize_iterations : 71	Epoch 11 --- Training Accuracy: 81.250%, Validation Accuracy: 82.812%, Validation Loss: 0.456
# Optimize_iterations : 72	Epoch 12 --- Training Accuracy: 77.344%, Validation Accuracy: 84.375%, Validation Loss: 0.414 *
# Optimize_iterations : 73	Epoch 13 --- Training Accuracy: 79.688%, Validation Accuracy: 79.688%, Validation Loss: 0.456
# Optimize_iterations : 74	Epoch 14 --- Training Accuracy: 82.812%, Validation Accuracy: 87.500%, Validation Loss: 0.367 *
# Optimize_iterations : 75	Epoch 0 --- Training Accuracy: 83.594%, Validation Accuracy: 75.000%, Validation Loss: 0.523
# Optimize_iterations : 76	Epoch 1 --- Training Accuracy: 71.875%, Validation Accuracy: 75.000%, Validation Loss: 0.548
# Optimize_iterations : 77	Epoch 2 --- Training Accuracy: 80.469%, Validation Accuracy: 85.938%, Validation Loss: 0.360 *
# Optimize_iterations : 78	Epoch 3 --- Training Accuracy: 84.375%, Validation Accuracy: 81.250%, Validation Loss: 0.506
# Optimize_iterations : 79	Epoch 4 --- Training Accuracy: 86.719%, Validation Accuracy: 84.375%, Validation Loss: 0.451
# Optimize_iterations : 80	Epoch 5 --- Training Accuracy: 91.406%, Validation Accuracy: 90.625%, Validation Loss: 0.365
# Optimize_iterations : 81	Epoch 6 --- Training Accuracy: 89.062%, Validation Accuracy: 89.062%, Validation Loss: 0.361
# Optimize_iterations : 82	Epoch 7 --- Training Accuracy: 88.281%, Validation Accuracy: 84.375%, Validation Loss: 0.365
# Optimize_iterations : 83	Epoch 8 --- Training Accuracy: 88.281%, Validation Accuracy: 90.625%, Validation Loss: 0.341 *
# Optimize_iterations : 84	Epoch 9 --- Training Accuracy: 84.375%, Validation Accuracy: 89.062%, Validation Loss: 0.302 *
# Optimize_iterations : 85	Epoch 10 --- Training Accuracy: 88.281%, Validation Accuracy: 87.500%, Validation Loss: 0.374
# Optimize_iterations : 86	Epoch 11 --- Training Accuracy: 83.594%, Validation Accuracy: 89.062%, Validation Loss: 0.336
# Optimize_iterations : 87	Epoch 12 --- Training Accuracy: 83.594%, Validation Accuracy: 81.250%, Validation Loss: 0.428
# Optimize_iterations : 88	Epoch 13 --- Training Accuracy: 83.594%, Validation Accuracy: 78.125%, Validation Loss: 0.526
# Optimize_iterations : 89	Epoch 14 --- Training Accuracy: 89.844%, Validation Accuracy: 87.500%, Validation Loss: 0.314
# Optimize_iterations : 90	Epoch 0 --- Training Accuracy: 85.156%, Validation Accuracy: 87.500%, Validation Loss: 0.423
# Optimize_iterations : 91	Epoch 1 --- Training Accuracy: 85.938%, Validation Accuracy: 85.938%, Validation Loss: 0.383
# Optimize_iterations : 92	Epoch 2 --- Training Accuracy: 90.625%, Validation Accuracy: 85.938%, Validation Loss: 0.327
# Optimize_iterations : 93	Epoch 3 --- Training Accuracy: 93.750%, Validation Accuracy: 93.750%, Validation Loss: 0.304
# Optimize_iterations : 94	Epoch 4 --- Training Accuracy: 91.406%, Validation Accuracy: 90.625%, Validation Loss: 0.228 *
# Optimize_iterations : 95	Epoch 5 --- Training Accuracy: 87.500%, Validation Accuracy: 92.188%, Validation Loss: 0.223 *
# Optimize_iterations : 96	Epoch 6 --- Training Accuracy: 90.625%, Validation Accuracy: 92.188%, Validation Loss: 0.270
# Optimize_iterations : 97	Epoch 7 --- Training Accuracy: 90.625%, Validation Accuracy: 90.625%, Validation Loss: 0.307
# Optimize_iterations : 98	Epoch 8 --- Training Accuracy: 89.844%, Validation Accuracy: 87.500%, Validation Loss: 0.331
# Optimize_iterations : 99	Epoch 9 --- Training Accuracy: 87.500%, Validation Accuracy: 84.375%, Validation Loss: 0.313
# Optimize_iterations : 100	Epoch 10 --- Training Accuracy: 88.281%, Validation Accuracy: 84.375%, Validation Loss: 0.392
# End Time : 2018-05-03 20:00:55
# Time elapsed: 4:52:32

# %%
validation_performance(show_confusion_matrix=True , show_example_errors=True)
# Out:
# Accuracy on Validate-Set: 80.222% (361 / 450)
# Example errors:
# Confusion Matrix:
# [[200  25]
#  [ 64 161]]

# %% [markdown]
# ## Restore Best Variables
#
# Re-load all the variables that were saved to file during optimization.

# %%
saver.restore(sess=session, save_path=save_path)
# Out:
# INFO:tensorflow:Restoring parameters from D:\FaamruProject_kor\Model\checkpoints\20180430\best_validate_1500_basicCNN

# %%
validation_performance(show_confusion_matrix=True , show_example_errors=False)
# Out:
# Accuracy on Validate-Set: 82.000% (369 / 450)
# Confusion Matrix:
# [[184  41]
#  [ 40 185]]

# %% [markdown]
# ## Visualization of Weights and Layers

# %% [markdown]
# ### plotting convolutional weights

# %%
def plot_conv_weights(weights, input_channel=0):
    w = session.run(weights)

    # Get the lowest and highest values for the weights.
    w_min = np.min(w)
    w_max = np.max(w)

    # Number of filters used in the conv. layer.
    num_filters = w.shape[3]

    # Number of grids to plot.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids)

    # Plot all the filter-weights.
    for i, ax in enumerate(axes.flat):
        if i<num_filters:
            # Get the weights for the i'th filter of the input channel.
            img = w[:, :, input_channel, i]

            # Plot image.
            ax.imshow(img, vmin=w_min, vmax=w_max, interpolation='nearest', cmap='seismic')
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# ### plotting the output of a convolutional layer

# %%
def plot_conv_layer(layer, image):
   
    image = image.reshape(img_size_flat)

    # Create a feed-dict containing just one image.
    feed_dict = {x: [image]}

    # Calculate and retrieve the output values of the layer when inputting that image.
    values = session.run(layer, feed_dict=feed_dict)

    # Number of filters used in the conv. layer.
    num_filters = values.shape[3]

    # Number of grids to plot.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids)

    # Plot the output images of all the filters.
    for i, ax in enumerate(axes.flat):
        if i<num_filters:
            # Get the output image of using the i'th filter.
            img = values[0, :, :, i]

            # Plot image.
            ax.imshow(img, interpolation='nearest', cmap='binary')
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    plt.show()

# %% [markdown]
# ### Input Testing - Images

# %% [markdown]
# function for plotting an image.

# %%
def plot_image(image):
    plt.imshow(image.reshape(img_size, img_size, num_channels),
               interpolation='nearest')
    plt.xticks([])
    plt.yticks([])

    plt.show()

# %% [markdown]
# Plot an image from the test-set which will be used as an example below.

# %%
image1 = datatest.images[6]
plot_image(image1)

# %% [markdown]
# Plot another example image from the test-set.

# %%
image2 = datatest.images[30]
plot_image(image2)

# %% [markdown]
# # Plot Images Output of Convolution Layer and Weight of each Layer

# %% [markdown]
# ### Convolution Layer 1

# %% [markdown]
# weight of Convolution Layer 1

# %%
plot_conv_weights(weights=weights_conv1)

# %% [markdown]
# output of images in convolutional layer 1

# %%
plot_conv_layer(layer=layer_conv1, image=image1)

# %% [markdown]
# ### Convolution Layer 2

# %% [markdown]
# weight of Convolution Layer 2

# %%
plot_conv_weights(weights=weights_conv2)

# %% [markdown]
# output of images in convolutional layer 1

# %%
plot_conv_layer(layer=layer_conv2, image=image1)

# %% [markdown]
# ### Convolution Layer 3

# %% [markdown]
# weight of Convolution Layer 3

# %%
plot_conv_weights(weights=weights_conv3)

# %% [markdown]
# output of images in convolutional layer 2

# %%
plot_conv_layer(layer=layer_conv3, image=image1)

# %% [markdown]
# ### Write Test Predictions to CSV

# %%
def plot_test_image(image , result):
    
    result_list = result.values.T.tolist()
   
    # Number of filters used in the conv. layer.
    num_filters = result.shape[0]

    # Number of grids to plot.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids,figsize=(15,15))
    fig.subplots_adjust(hspace=0.8, wspace=0.2)

    # Plot the output images of all the filters.
    for i, ax in enumerate(axes.flat):
        if i<num_filters:
            # Get the output image of using the i'th filter.
            img = image[i]

            # Plot image.
            ax.imshow(cv2.cvtColor(img.reshape(img_shape_wChnls), cv2.COLOR_BGR2RGB), interpolation = 'bicubic' )
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
        
        xlabel = '{0} \nTrue : {1} \nPred : Veg :{2}\n       notV : {3}'.format(result_list[0][i] , result_list[1][i] ,\
                                                                               result_list[2][i] , \
                                                                               result_list[3][i])
        ax.set_xlabel(xlabel)
        
        if i == num_filters-1 :
            break
            
            
    plt.xticks([])
    plt.yticks([])
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %%
def predictions(ims, cls , ids , write_file=True , plot_testing=False):

    images_test = ims.reshape(ims.shape[0], img_size_flat)
    num_test = len(images_test)
    
    i = 0
    ims_test_pred = list()
    images_test_pred = list()
    
    saver.restore(sess=session, save_path=save_path)

    while i < num_test:
        # The ending index for the next batch is denoted j.
        j = min(i + validate_batch_size, num_test)

        # Get the images from the test-set between index i and j.
        images = images_test[i:j, :]
        
        # Calculate the predicted class using TensorFlow.
        
        ims_test_pred = session.run(y_pred, feed_dict={x: images})
        images_test_pred.extend(ims_test_pred)
        
        # Set the start-index for the next batch to the
        # end-index of the current batch.
        i = j

        result = pd.DataFrame(images_test_pred, columns=classes)
    
    
    result['vegetation'] = pd.Series(["{0:.2f}%".format(val * 100) for val in result['vegetation']], index = result.index)
    result['notVegetation'] = pd.Series(["{0:.2f}%".format(val * 100) for val in result['notVegetation']], index = result.index)
    result.insert(loc=0, column='ids', value=ids)
    result.insert(loc=1, column='labels', value=cls)
    
    result['predicted'] = np.where(result['vegetation'] >= result['notVegetation'], 'vegetation', 'notVegetation')
    
    if plot_testing:
        plot_test_image(ims, result)
    
    pred_file = 'predictions_{}.csv'.format(time.strftime('%Y%m%d_%H%M%S', time.localtime(time.time())))
    
    if write_file:
        result.to_csv(pred_file, index=False) 
    
    result_list = result.values.T.tolist()
    result_labels = result_list[1]
    result_predicted = result_list[4]
    
    cm = confusion_matrix(y_true=result_labels,
                          y_pred=result_predicted)
    
    correct_prediction = tf.equal(result_predicted, result_labels)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    accuracy_testimages = session.run(accuracy)

    print('===== Result of prediction Images ======')   
    print(result)

    print('===== Confusion Matrix ======')
    print(cm)
    
    print('Accuracy of Test Images : {0:.2f}%'.format(accuracy_testimages*100))

# %%
predictions(datatest.images, datatest.cls, datatest.ids , write_file=True , plot_testing=False)
# Out:
# INFO:tensorflow:Restoring parameters from D:\FaamruProject_kor\Model\checkpoints\20180430\best_validate_1500_basicCNN
# ===== Result of prediction Images ======
#            ids         labels vegetation notVegetation      predicted
# 0    10007.png     vegetation     74.44%        25.56%     vegetation
# 1    10162.png     vegetation     79.65%        20.35%     vegetation
# 2    10217.png     vegetation     82.57%        17.43%     vegetation
# 3    10268.png     vegetation     27.12%        72.88%  notVegetation
# 4    10272.png     vegetation     71.83%        28.17%     vegetation
# 5    10280.png     vegetation     74.97%        25.03%     vegetation
# 6    10310.png     vegetation     74.47%        25.53%     vegetation
# 7    10659.png     vegetation     78.19%        21.81%     vegetation
# 8    10667.png     vegetation     76.64%        23.36%     vegetation
# 9    10806.png     vegetation     70.66%        29.34%     vegetation
# 10    1121.png     vegetation     79.12%        20.88%     vegetation
# 11   11330.png     vegetation     87.75%        12.25%     vegetation
# 12   11465.png     vegetation     79.31%        20.69%     vegetation
# 13   11555.png     vegetation     70.48%        29.52%     vegetation
# 14   11712.png     vegetation     86.71%        13.29%     vegetation
# 15   11732.png     vegetation     68.19%        31.81%     vegetation
# 16   11738.png     vegetation     88.15%        11.85%     vegetation
# 17   11822.png     vegetation     71.03%        28.97%     vegetation
# 18   11908.png     vegetation     91.81%         8.19%     vegetation
# 19   11945.png     vegetation     76.63%        23.37%     vegetation
# 20   11954.png     vegetation     80.71%        19.29%     vegetation
# 21   12032.png     vegetation     38.63%        61.37%  notVegetation
# 22   12089.png     vegetation     55.88%        44.12%     vegetation
# 23   12100.png     vegetation     68.87%        31.13%     vegetation
# 24    1211.png     vegetation     47.29%        52.71%  notVegetation
# 25     126.png     vegetation     37.87%        62.13%  notVegetation
# 26    1365.png     vegetation     80.41%        19.59%     vegetation
# 27     140.png     vegetation     67.41%        32.59%     vegetation
# 28    1419.png     vegetation     95.80%         4.20%     vegetation
# 29    1483.png     vegetation     93.36%         6.64%     vegetation
# ..         ...            ...        ...           ...            ...
# 285   7958.png  notVegetation     11.12%        88.88%  notVegetation
# 286   7961.png  notVegetation      1.87%        98.13%  notVegetation
# 287   7992.png  notVegetation     26.60%        73.40%  notVegetation
# 288   8003.png  notVegetation      6.98%        93.02%  notVegetation
# 289   8019.png  notVegetation      5.36%        94.64%  notVegetation
# 290   8065.png  notVegetation     12.09%        87.91%  notVegetation
# 291   8090.png  notVegetation      1.38%        98.62%  notVegetation
# 292   8106.png  notVegetation     47.56%        52.44%  notVegetation
# 293   8145.png  notVegetation     43.27%        56.73%  notVegetation
# 294   8286.png  notVegetation      7.57%        92.43%  notVegetation
# 295   8314.png  notVegetation      7.42%        92.58%  notVegetation
# 296   8359.png  notVegetation      7.43%        92.57%  notVegetation
# 297   8402.png  notVegetation     46.04%        53.96%  notVegetation
# 298   8412.png  notVegetation      7.93%        92.07%  notVegetation
# 299   8459.png  notVegetation     21.52%        78.48%  notVegetation
# 300   8461.png  notVegetation     24.45%        75.55%  notVegetation
# 301   8535.png  notVegetation      6.81%        93.19%  notVegetation
# 302   8540.png  notVegetation     30.81%        69.19%  notVegetation
# 303   8544.png  notVegetation     16.51%        83.49%  notVegetation
# 304   8564.png  notVegetation     67.27%        32.73%     vegetation
# 305   8583.png  notVegetation     11.88%        88.12%  notVegetation
# 306   8615.png  notVegetation     11.58%        88.42%  notVegetation
# 307   8624.png  notVegetation     28.60%        71.40%  notVegetation
# 308   8736.png  notVegetation     48.62%        51.38%  notVegetation
# 309   8802.png  notVegetation     24.47%        75.53%  notVegetation
# 310   8838.png  notVegetation     15.52%        84.48%  notVegetation
# 311   8931.png  notVegetation     15.88%        84.12%  notVegetation
# 312   8932.png  notVegetation     18.35%        81.65%  notVegetation
# 313   9218.png  notVegetation     24.13%        75.87%  notVegetation
# 314   9983.png  notVegetation     61.37%        38.63%     vegetation
#
# [315 rows x 5 columns]
# ===== Confusion Matrix ======
# [[129  28]
#  [ 31 127]]
# Accuracy of Test Images : 81.27%

# %%
session.close()
