# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.utils import shuffle
from datetime import timedelta
import time
import math
import sys
import cv2
import os
import random
import glob

# %%
tf.__version__
# Out:
# '1.2.1'

# %%
sys.version
# Out:
# '3.6.0 |Anaconda 4.3.0 (64-bit)| (default, Dec 23 2016, 11:57:41) [MSC v.1900 64 bit (AMD64)]'

# %%
# Convolutional Layer 1.
filter_size1 = 5          # Convolution filters are 5 x 5 pixels.
num_filters1 = 32         # There are 32 of these filters.

# Convolutional Layer 2.
filter_size2 = 3          # Convolution filters are 3 x 3 pixels.
num_filters2 = 16         # There are 16 of these filters.

# Convolutional Layer 3.
filter_size3 = 3          # Convolution filters are 3 x 3 pixels.
num_filters3 = 16         # There are 16 of these filters.

# Fully-connected layer.
fc_size_1 = 512             # Number of neurons in fully-connected layer.

fc_size_2 = 128             # Number of neurons in fully-connected layer.

# %%
# Number of colour channels for the images: 4 channel for RGB and Transparent .
num_channels = 4

# We know that Satellite images are 640 pixels in each dimension.
img_size = 640

# Images are stored in one-dimensional arrays of this length.
img_size_flat = img_size * img_size * num_channels

# Tuple with height and width of images used to reshape arrays.
img_shape = (img_size, img_size)
img_shape_wChnls = (img_size, img_size, num_channels)

# class info
classes = ['vegetation', 'notVegetation']
# Number of classes, one class for each of 2 digits like Green and NotGreen.
num_classes = len(classes)

dropout_rate = 0.25

# %%
num_classes
# Out:
# 2

# %% [markdown]
# # Pre-processing Data

# %% [markdown]
# ## Convert Images to Array and group by dataset

# %% [markdown]
# identify feature of images , labels etc.

# %%
class DataSet(object):

    def __init__(self, images, labels, ids, cls):
        """Construct a DataSet. one_hot arg is used only if fake_data is true."""

        self._num_examples = images.shape[0]


        # Convert shape from [num examples, rows, columns, depth]
        # to [num examples, rows*columns] (assuming depth == 1)
        # Convert from [0, 255] -> [0.0, 1.0].

        images = images.astype(np.float32)
        images = np.multiply(images, 1.0 / 255.0)

        self._images = images
        self._labels = labels
        self._ids = ids
        self._cls = cls
        self._epochs_completed = 0
        self._index_in_epoch = 0

    @property
    def images(self):
        return self._images

    @property
    def labels(self):
        return self._labels

    @property
    def ids(self):
        return self._ids

    @property
    def cls(self):
        return self._cls

    @property
    def num_examples(self):
        return self._num_examples

    @property
    def epochs_completed(self):
        return self._epochs_completed

    def next_batch(self, batch_size):
        start = self._index_in_epoch
        self._index_in_epoch += batch_size

        if self._index_in_epoch > self._num_examples:

            self._epochs_completed += 1

            start = 0
            self._index_in_epoch = batch_size
            assert batch_size <= self._num_examples
        end = self._index_in_epoch

        return self._images[start:end], self._labels[start:end], self._ids[start:end], self._cls[start:end]

# %% [markdown]
# load images from path directory

# %%
def load_and_split_data(train_path, image_size, classes):
    images = []
    labels = []
    ids = []
    cls = []

    print('Reading training images')
    for fld in classes:   # assuming data directory has a separate folder for each class, and that each folder is named after the class
        index = classes.index(fld)
        print('Loading {} files (Index: {})'.format(fld, index))
        path = os.path.join(train_path, fld, '*g')
        files = glob.glob(path)
        for fl in files:
            #image = cv2.imread(fl)                         # 3-channal
            image = cv2.imread(fl, cv2.IMREAD_UNCHANGED)    # 4-channal
            image = cv2.resize(image, (image_size, image_size), cv2.INTER_LINEAR)
            image = image.reshape(img_size_flat)
            images.append(image)
            label = np.zeros(len(classes))
            label[index] = 1.0
            labels.append(label)
            flbase = os.path.basename(fl)
            ids.append(flbase)
            cls.append(fld)
    images = np.array(images)
    labels = np.array(labels)
    ids = np.array(ids)
    cls = np.array(cls)

    return images, labels, ids, cls

# %% [markdown]
# read image and split to train , validate and test set

# %%
def read_train_sets(train_path, image_size, classes, validation_size=0):
    class DataSets(object):
        pass
    data_sets = DataSets()

    images, labels, ids, cls = load_and_split_data(train_path, image_size, classes)
    
    index_vegetation, = np.where(cls == classes[0] )
    index_notvegetation, = np.where(cls == classes[1] )
    
    if isinstance(validation_size, float):
        validation_size = int(validation_size * images.shape[0])
        
    balance_size = int( (len(images) - validation_size) / num_classes )
    index_random_vegetation = random.sample(list(index_vegetation), balance_size)
    index_random_notVegetation = random.sample(list(index_notvegetation), balance_size)
    index_random_balance = index_random_vegetation + index_random_notVegetation
    
    train_images = images[index_random_balance]
    train_labels  = labels[index_random_balance]
    train_ids  = ids[index_random_balance]
    train_cls  = cls[index_random_balance]
    
    validation_cls = np.delete(cls, index_random_balance)
    validation_ids = np.delete(ids, index_random_balance)
    validation_labels = np.delete(labels, index_random_balance, axis=0)
    validation_images = np.delete(images, index_random_balance, axis=0)   
    
    train_images, train_labels, train_ids, train_cls = shuffle(train_images, 
                                                               train_labels, 
                                                               train_ids, 
                                                               train_cls)  # shuffle the data
    validation_images, validation_labels, validation_ids, validation_cls = shuffle(validation_images, 
                                                                                   validation_labels, 
                                                                                   validation_ids, 
                                                                                   validation_cls)  # shuffle the data

    data_sets.train = DataSet(train_images, train_labels, train_ids, train_cls)
    data_sets.valid = DataSet(validation_images, validation_labels, validation_ids, validation_cls)

    return data_sets

def read_test_set(test_path, image_size, classes):
    class DataSets(object):
        pass
    datatest = DataSets()
    
    test_images, test_labels , test_ids , test_cls  = load_and_split_data(test_path, image_size, classes)
    
    datatest = DataSet(test_images, test_labels, test_ids, test_cls)
    
    return datatest

# %% [markdown]
# ## Load Image and convert to Array

# %%
# validation split
validation_size = .30

train_path = 'D:\FaamruProject_kor\Dataset\FaamruDS\_training'
test_path = 'D:\FaamruProject_kor\Dataset\FaamruDS\_testing'

# %%
data = read_train_sets(train_path, img_size, classes, validation_size=validation_size)
# Out:
# Reading training images
# Loading vegetation files (Index: 0)
# Loading notVegetation files (Index: 1)

# %%
datatest = read_test_set(test_path, img_size, classes)
# Out:
# Reading training images
# Loading vegetation files (Index: 0)
# Loading notVegetation files (Index: 1)

# %%
print("Size of Dataset :")
print("- Training-set\t\t: {}".format(len(data.train.labels)))
print("- Validation-set\t: {}".format(len(data.valid.labels)))
print("- Test-set(Unseen Data)\t: {}".format(len(datatest.images)))
# Out:
# Size of Dataset :
# - Training-set		: 1834
# - Validation-set	: 785
# - Test-set(Unseen Data)	: 655

# %%
data.train.images.shape
# Out:
# (1834, 1638400)

# %%
len(data.train.images[5])
# Out:
# 1638400

# %%
len(datatest.images[5])
# Out:
# 1638400

# %%
images = data.train.images
print('images[1]\t\t: ',images[1])
print('type of images[1]\t: ',type(images[1]))
print('shape of images[1]\t: ',images.shape)
print('len of images[1]\t: ',len(images[1]))
# Out:
# images[1]		:  [ 1.  1.  1. ...,  1.  1.  0.]
# type of images[1]	:  <class 'numpy.ndarray'>
# shape of images[1]	:  (1834, 1638400)
# len of images[1]	:  1638400

# %%
data.train.cls
# Out:
# array(['notVegetation', 'notVegetation', 'vegetation', ..., 'vegetation',
#        'notVegetation', 'vegetation'],
#       dtype='<U13')

# %%
vegetationT = sum(i == 'vegetation' for i in data.train.cls)
NotvegetationT = sum(i == 'notVegetation' for i in data.train.cls)
vegetationV = sum(i == 'vegetation' for i in data.valid.cls)
NotvegetationV = sum(i == 'notVegetation' for i in data.valid.cls)

# %%
print('train -> vegetation : ',vegetationT)
print('train -> notVegetation : ',NotvegetationT)
print('validate -> vegetation : ',vegetationV)
print('validate -> notVegetation : ',NotvegetationV)
# Out:
# train -> vegetation :  917
# train -> notVegetation :  917
# validate -> vegetation :  255
# validate -> notVegetation :  530

# %% [markdown]
# # Plotting Images

# %%
def index_random(data ,size):
    data_range = range(len(data))
    
    return random.sample(data_range, size)

# %%
### Plotting image by array data
def plot_img_new(images, cls_true , ids , cls_pred=None):  
    
    #features = data_arr[0]            # images
    #lables = data_arr[1]              # cls_true
    #images_filename = data_arr[2]     # ids 
    
    
    
    if len(images) <16 :
        indexs_random = range(len(images))
    else :
        indexs_random = index_random(images, 16)
        assert len(indexs_random) == 16
        
    fig, axes = plt.subplots(4, 4 ,figsize=(12,12))
    fig.subplots_adjust(hspace=0.3, wspace=0.1)
    
    for i, ax in enumerate(axes.flat):
                
        # Read PNG Image from Directory 
        feature_img = images[ indexs_random[i] ]
        
        # Plot image.
        ax.imshow(cv2.cvtColor(feature_img.reshape(img_shape_wChnls), cv2.COLOR_BGR2RGB), interpolation = 'bicubic' )
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])  # to hide tick values on X and Y axis
        
        # Show the Title of images.
        ax.set_title('Pic : {0}'.format( ids[indexs_random[i]] ))
        
        #Show True and Predicted classes
        if cls_pred is None:
            xlabel = 'True : {0}'.format( cls_true[indexs_random[i]] )
        else:
            xlabel = 'True : {0}, \nPred : {1}'.format( cls_true[indexs_random[i]] , cls_pred[i])
        
        ax.set_xlabel(xlabel)
        
        
        
    plt.show()

# %%
print('')
print('\t\t*** Training Data : Sampling 16 images of {} images *** '.format(len(data.train.images)))

# Get the first images from the trainning-set.
images_train = data.train.images

# Get the true classes for those images.
cls_true_train = data.train.cls

# Get the file names for those images.
ids_filename_train = data.train.ids

# Plot the images and labels using our helper-function above.
plot_img_new(images=images_train, cls_true=cls_true_train , ids=ids_filename_train)
# Out:
# 		*** Training Data : Sampling 16 images of 1834 images ***

# %%
print('')
print('\t\t*** Validation Data : Sampling 16 images of {} images *** '.format(len(data.valid.images)))

# Get the first images from the validate-set.
images_validate = data.valid.images

# Get the true classes for those images.
cls_true_validate = data.valid.cls

# Get the file names for those images.
ids_filename_validate = data.valid.ids

plot_img_new(images=images_validate, cls_true=cls_true_validate , ids=ids_filename_validate)
# Out:
# 		*** Validation Data : Sampling 16 images of 785 images ***

# %% [markdown]
# # TensorFlow Graph

# %% [markdown]
# create component in model by my designing

# %% [markdown]
# # Creating New Variables

# %%
def new_weights(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.05))

# %%
def new_biases(length):
    return tf.Variable(tf.constant(0.05, shape=[length]))

# %% [markdown]
# # Creating a Convolutional Layer

# %%
def conv_layer(input,         # The previous layer.
                   num_input_channels, # Num. channels in prev. layer.
                   filter_size,        # Width and height of each filter.
                   num_filters,        # Number of filters.
                   use_pooling=True):  # Use 2x2 max-pooling.

    # Shape of the filter-weights for the convolution.
    shape = [filter_size, filter_size, num_input_channels, num_filters]

    # Create new weights aka. filters with the given shape.
    weights = new_weights(shape=shape)

    # Create new biases, one for each filter.
    biases = new_biases(length=num_filters)

    # Create the TensorFlow operation for convolution.
    layer = tf.nn.conv2d(input=input,
                         filter=weights,
                         strides=[1, 1, 1, 1],
                         padding='SAME')

    # Add the biases to the results of the convolution.
    layer += biases

    # Use pooling to down-sample the image resolution?
    if use_pooling:
        layer = tf.nn.max_pool(value=layer,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME')

    # Rectified Linear Unit (ReLU).
    layer = tf.nn.relu(layer)

    return layer, weights

# %% [markdown]
# # Creating a Full-Connected Layer

# %%
def flatten_layer(layer):
    # Get the shape of the input layer.
    layer_shape = layer.get_shape()

    num_features = layer_shape[1:4].num_elements()
    
    layer_flat = tf.reshape(layer, [-1, num_features])

    return layer_flat, num_features

# %%
def dropout_layer(input,dropout_rate,traning_mode):
    features = input
    dropout_layer = tf.layers.dropout(features,rate=dropout_rate,training=traning_mode)
    
    return dropout_layer

# %%
def fc_layer(input,          # The previous layer.
                 num_inputs,     # Num. inputs from prev. layer.
                 num_outputs,    # Num. outputs.
                 use_relu=True): # Use Rectified Linear Unit (ReLU)?

    # Create new weights and biases.
    weights = new_weights(shape=[num_inputs, num_outputs])
    biases = new_biases(length=num_outputs)

    # Calculate the layer as the matrix multiplication of
    layer = tf.matmul(input, weights) + biases

    # Use ReLU?
    if use_relu:
        layer = tf.nn.relu(layer)

    return layer

# %% [markdown]
# ### Placeholder variables

# %%
x = tf.placeholder(tf.float32, shape=[None, img_size_flat], name='x') #img_size_flat 640 x 640

# %%
x_image = tf.reshape(x, [-1, img_size, img_size, num_channels])

# %%
y_true = tf.placeholder(tf.float32, shape=[None, num_classes], name='y_true')

# %%
y_true_cls = tf.argmax(y_true, axis=1)

# %% [markdown]
# ### Convolutional Layer 1

# %%
layer_conv1, weights_conv1 = conv_layer(input=x_image,  #image_dataset
                   num_input_channels=num_channels,     #number_channal=4
                   filter_size=filter_size1,            #filter_size = 5 x 5
                   num_filters=num_filters1,            #number_filter = 32
                   use_pooling=True)                    #max_pooling = 2x2 , stride = 2 step

# %%
layer_conv1
# Out:
# <tf.Tensor 'Relu:0' shape=(?, 320, 320, 32) dtype=float32>

# %% [markdown]
# ### Convolutional Layer 2

# %%
layer_conv2, weights_conv2 = conv_layer(input=layer_conv1,  #image_dataset
                   num_input_channels=num_filters1,         #number_channal is num_filter 0f conv. layer 1 = 32 
                   filter_size=filter_size2,                #filter_size = 3 x 3
                   num_filters=num_filters2,                #number_filter = 16
                   use_pooling=True)                        #max_pooling = 2x2 , stride = 2 step

# %%
layer_conv2
# Out:
# <tf.Tensor 'Relu_1:0' shape=(?, 160, 160, 16) dtype=float32>

# %% [markdown]
# ### Convolutional Layer 3

# %%
layer_conv3, weights_conv3 = conv_layer(input=layer_conv2,  #image_dataset
                   num_input_channels=num_filters2,         #number_channal is num_filter 0f conv. layer 1 = 32 
                   filter_size=filter_size3,                #filter_size = 3 x 3
                   num_filters=num_filters3,                #number_filter = 16
                   use_pooling=True)                        #max_pooling = 2x2 , stride = 2 step

# %%
layer_conv3
# Out:
# <tf.Tensor 'Relu_2:0' shape=(?, 80, 80, 16) dtype=float32>

# %% [markdown]
# ### Flatten Layer 1

# %%
layer_flat, num_features = flatten_layer(layer_conv3)

# %%
layer_flat
# Out:
# <tf.Tensor 'Reshape_1:0' shape=(?, 102400) dtype=float32>

# %%
num_features
# Out:
# 102400

# %% [markdown]
# ### Full-Connected Layer 1

# %%
layer_fc1 = fc_layer(input=layer_flat,
                         num_inputs=num_features,
                         num_outputs=fc_size_1,          #fc_size =  512
                         use_relu=True)

# %%
layer_fc1
# Out:
# <tf.Tensor 'Relu_3:0' shape=(?, 512) dtype=float32>

# %% [markdown]
# ### Dropout Layer 1

# %%
layer_dropout1 = dropout_layer(input=layer_fc1,
                         dropout_rate=dropout_rate,
                         traning_mode=True)

# %%
layer_dropout1
# Out:
# <tf.Tensor 'dropout/dropout/mul:0' shape=(?, 512) dtype=float32>

# %% [markdown]
# ### Full-Connected Layer 2

# %%
layer_fc2 = fc_layer(input=layer_dropout1,
                         num_inputs=fc_size_1,
                         num_outputs=fc_size_2,          #fc_size = 128 
                         use_relu=True)

# %%
layer_fc2
# Out:
# <tf.Tensor 'Relu_4:0' shape=(?, 128) dtype=float32>

# %% [markdown]
# ### Dropout Layer 2

# %%
layer_dropout2 = dropout_layer(input=layer_fc2,
                         dropout_rate=dropout_rate,
                         traning_mode=True)

# %%
layer_dropout2
# Out:
# <tf.Tensor 'dropout_2/dropout/mul:0' shape=(?, 128) dtype=float32>

# %% [markdown]
# ### Full-Connected Layer 3

# %%
layer_fc3 = fc_layer(input=layer_dropout2,
                         num_inputs=fc_size_2,
                         num_outputs=num_classes,          #fc_size = 2 class _ output
                         use_relu=False)

# %%
layer_fc3
# Out:
# <tf.Tensor 'add_5:0' shape=(?, 2) dtype=float32>

# %% [markdown]
# # Predicted Class

# %% [markdown]
# Generate Predictions

# %%
y_pred = tf.nn.softmax(layer_fc3)  #probabilities

# %%
y_pred_cls = tf.argmax(y_pred, axis=1)    #classes

# %% [markdown]
# # Cost-function to be optimized

# %%
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=layer_fc3,
                                                        labels=y_true)

# %%
cost = tf.reduce_mean(cross_entropy)

# %% [markdown]
# # Optimization Method

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(cost) #'learning_rate': 0.0001

# %% [markdown]
# # Performance Measures

# %% [markdown]
# this section is create values to confusion matrix

# %%
correct_prediction = tf.equal(y_pred_cls, y_true_cls)

# %%
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %% [markdown]
# ### Saver

# %%
saver = tf.train.Saver()

# %%
save_dir = 'D:\FaamruProject_kor\Model\checkpoints\_3274'

# %%
date_create = "{}".format(time.strftime('%Y%m%d', time.localtime(time.time())))

# %%
save_dir_date = os.path.join(save_dir, date_create)
if not os.path.exists(save_dir_date):
    os.makedirs(save_dir_date)

# %%
name_directory_best_validation = 'best_validate_3274_randomdata'

# %%
name_directory_best_validation
# Out:
# 'best_validate_3274_randomdata'

# %%
save_path = os.path.join(save_dir_date, name_directory_best_validation)

# %%
save_path
# Out:
# 'D:\\FaamruProject_kor\\Model\\checkpoints\\_3274\\20180503\\best_validate_3274_randomdata'

# %% [markdown]
# # TensorFlow Run

# %%
#Create TensorFlow session

session = tf.Session()

#Initialize variables

session.run(tf.global_variables_initializer())

# %% [markdown]
# function to perform optimization iterations

# %%
train_batch_size = 128

# %%
validate_batch_size = 64

# %%
# Best validation accuracy seen so far.
best_validation_loss = 1.0

# Iteration-number for last improvement to validation accuracy.
last_improvement = 0

# Stop optimization if no improvement found in this many iterations.
require_improvement = 5000

# %%
def print_progress(number_data_loop, optimize_iterations, epoch, feed_dict_train, feed_dict_validate, val_loss , improved_str):
    # Calculate the accuracy on the training-set.
    acc = session.run(accuracy, feed_dict=feed_dict_train)
    val_acc = session.run(accuracy, feed_dict=feed_dict_validate)
    msg = "Data : {0}  iterations : {1}  Epoch {2} --- Training Accuracy: {3:>6.3%}, Validation Accuracy: {4:>6.3%}, Validation Loss: {5:.3f} {6}"
    print(msg.format(number_data_loop, optimize_iterations,epoch , acc, val_acc, val_loss , improved_str))

# %%
# Counter for total number of iterations performed so far.
total_iterations = 0

def train_optimize(num_iterations , continue_iterate=False, number_random_data=1):
    # Ensure we update the global variable rather than a local copy.
    global total_iterations
    global best_validation_loss         #20180329
    global last_improvement             #20180329
    global patience
    global require_improvement
    
    number_batch_epoch = 0

    # Start-time used for printing time-usage below.
    start_time = time.time()
    print("Start Time : " + time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())))  
    
    for number_loop in range(1, number_random_data+1):
        
        data = read_train_sets(train_path, img_size, classes, validation_size=validation_size)

        for i in range(total_iterations,
                       total_iterations + num_iterations):

            # Get a batch of training examples.
            x_batch, y_true_batch, _, cls_batch = data.train.next_batch(train_batch_size)
            x_valid_batch, y_valid_batch, _, valid_cls_batch = data.valid.next_batch(validate_batch_size)

            # Put the batch into a dict with the proper names
            feed_dict_train = {x: x_batch,
                               y_true: y_true_batch}

            feed_dict_validate = {x: x_valid_batch,
                                  y_true: y_valid_batch}

            # Run the optimizer using this batch of training data.
            session.run(optimizer, feed_dict=feed_dict_train)


            # Print status at end of each epoch (defined as full pass through training dataset).

            #if i % int(data.train.num_examples/train_batch_size) == 0: 
            val_loss = session.run(cost, feed_dict=feed_dict_validate)
            if number_batch_epoch < int(data.train.num_examples/train_batch_size):
                number_batch_epoch += 1
            else:
                number_batch_epoch = 0
            optimize_iterations = i+1

            if require_improvement:    
                if val_loss < best_validation_loss:
                    best_validation_loss = val_loss
                    last_improvement = 0
                    saver.save(sess=session, save_path=save_path)
                    improved_str = '*'
                else:
                    last_improvement += 1
                    improved_str = ''

                if last_improvement == require_improvement:
                    break

            print_progress(number_loop, optimize_iterations,number_batch_epoch, feed_dict_train, feed_dict_validate, val_loss , improved_str)

    # Update the total number of iterations performed.
    if continue_iterate:
        total_iterations += num_iterations

    # Ending time.
    end_time = time.time()
    print("End Time : " + time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(end_time)))

    # Difference between start and end-times.
    time_dif = end_time - start_time

    # Print the time-usage.
    print("Time elapsed: " + str(timedelta(seconds=int(round(time_dif)))))

# %% [markdown]
# function to plot example errors

# %%
def plot_example_errors(cls_pred, correct):

    # Negate the boolean array.
    incorrect = (correct == False)
    
    # Get the images from the test-set that have been
    # incorrectly classified.
    images = data.valid.images[incorrect]
    ids = data.valid.ids[incorrect]
    
    # Get the predicted classes for those images.
    cls_pred = cls_pred[incorrect]

    # Get the true classes for those images.
    cls_true = data.valid.cls[incorrect]
    
       
    plot_errors_image(images=images,
                cls_true=cls_true,
                ids=ids,
                cls_pred=cls_pred)

# %%
def plot_errors_image(images , cls_true , ids , cls_pred):
      
    # Number of filters used in the conv. layer.
    num_filters = images.shape[0]

    # Number of grids to plot.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids,figsize=(15,15))
    fig.subplots_adjust(hspace=0.8, wspace=0.2)

    # Plot the output images of all the filters.
    for i, ax in enumerate(axes.flat):
        if i<num_filters:
            # Get the output image of using the i'th filter.
            img = images[i]

            # Plot image.
            ax.imshow(cv2.cvtColor(img.reshape(img_shape_wChnls), cv2.COLOR_BGR2RGB), interpolation = 'bicubic' )
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
        
        xlabel = '{0} \nTrue : {1} \nPred : {2}'.format(ids[i] , cls_true[i] , cls_pred[i])
        ax.set_xlabel(xlabel)
        
        if i == num_filters-1 :
            break
            
            
    plt.xticks([])
    plt.yticks([])

    plt.show()

# %% [markdown]
# function to plot confusion matrix

# %%
def plot_confusion_matrix(cls_pred):
    # cls_pred is an array of the predicted class-number for all images in the test-set.

    # Get the true classifications for the test-set.
    cls_true = data.valid.cls
    
    # Get the confusion matrix using sklearn.
    cm = confusion_matrix(y_true=cls_true,
                          y_pred=cls_pred)

    # Print the confusion matrix as text.
    print(cm)

    # Plot the confusion matrix as an image.
    plt.matshow(cm)
    
    # Print the Recall - Precision - F1 score.
    #print('Recall : ',metrics.recall_score( cls_true , cls_pred ))
    
    

    # Make various adjustments to the plot.
    plt.colorbar()
    tick_marks = np.arange(num_classes)
    plt.xticks(tick_marks, range(num_classes))
    plt.yticks(tick_marks, range(num_classes))
    plt.xlabel('Predicted')
    plt.ylabel('True')

    plt.show()

# %% [markdown]
# function for showing the performance

# %%
def validation_performance(show_example_errors=False,
                        show_confusion_matrix=False):

    # Number of images in the test-set.
    num_test = len(data.valid.images)

    cls_pred = np.zeros(shape=num_test, dtype=np.int)


    i = 0

    while i < num_test:
        # The ending index for the next batch is denoted j.
        j = min(i + validate_batch_size, num_test)

        # Get the images from the test-set between index i and j.
        images = data.valid.images[i:j, :]
        

        # Get the associated labels.
        labels = data.valid.labels[i:j, :]

        # Create a feed-dict with these images and labels.
        feed_dict = {x: images,
                     y_true: labels}

        # Calculate the predicted class using TensorFlow.
        cls_pred[i:j] = session.run(y_pred_cls, feed_dict=feed_dict)

        # Set the start-index for the next batch to the
        # end-index of the current batch.
        i = j

    cls_true = np.array(data.valid.cls)
    cls_pred = np.array([classes[x] for x in cls_pred]) 

    # Create a boolean array whether each image is correctly classified.
    correct = (cls_true == cls_pred)

    # Calculate the number of correctly classified images.
    correct_sum = correct.sum()

    acc = float(correct_sum) / num_test

    # Print the accuracy.
    msg = "Accuracy on Validate-Set: {0:.3%} ({1} / {2})"
    print(msg.format(acc, correct_sum, num_test))

    # Plot some examples of mis-classifications, if desired.
    if show_example_errors:
        print("Example errors:")
        plot_example_errors(cls_pred=cls_pred, correct=correct)

    # Plot the confusion matrix, if desired.
    if show_confusion_matrix:
        print("Confusion Matrix:")
        plot_confusion_matrix(cls_pred=cls_pred)

# %% [markdown]
# ## Performance after 1 optimization iteration

# %%
train_optimize(num_iterations=1, number_random_data=3)
# Out:
# Start Time : 2018-05-03 22:15:54
# Reading training images
# Loading vegetation files (Index: 0)
# Loading notVegetation files (Index: 1)
# Data : 1  iterations : 1  Epoch 1 --- Training Accuracy: 57.812%, Validation Accuracy: 31.250%, Validation Loss: 0.950 *
# Reading training images
# Loading vegetation files (Index: 0)
# Loading notVegetation files (Index: 1)
# Data : 2  iterations : 1  Epoch 2 --- Training Accuracy: 56.250%, Validation Accuracy: 29.688%, Validation Loss: 0.923 *
# Reading training images
# Loading vegetation files (Index: 0)
# Loading notVegetation files (Index: 1)
# Data : 3  iterations : 1  Epoch 3 --- Training Accuracy: 52.344%, Validation Accuracy: 34.375%, Validation Loss: 0.766 *
# End Time : 2018-05-03 22:27:05
# Time elapsed: 0:11:11

# %%
validation_performance()
# Out:
# Accuracy on Validate-Set: 33.885% (266 / 785)

# %% [markdown]
# ## Performance after 100 optimization iterations
#
# After 100 optimization iterations, the model should have significantly improved its classification accuracy.

# %%
#Initialize variables

session.run(tf.global_variables_initializer())

# %%
train_optimize(num_iterations=100 , number_random_data=3)
# Out:
# Start Time : 2018-05-03 22:35:57
# Reading training images
# Loading vegetation files (Index: 0)
# Loading notVegetation files (Index: 1)
# Data : 1  iterations : 1  Epoch 1 --- Training Accuracy: 55.469%, Validation Accuracy: 40.625%, Validation Loss: 1.372
# Data : 1  iterations : 2  Epoch 2 --- Training Accuracy: 56.250%, Validation Accuracy: 50.000%, Validation Loss: 0.816
# Data : 1  iterations : 3  Epoch 3 --- Training Accuracy: 50.781%, Validation Accuracy: 67.188%, Validation Loss: 0.680 *
# Data : 1  iterations : 4  Epoch 4 --- Training Accuracy: 53.906%, Validation Accuracy: 65.625%, Validation Loss: 0.720
# Data : 1  iterations : 5  Epoch 5 --- Training Accuracy: 54.688%, Validation Accuracy: 62.500%, Validation Loss: 0.637 *
# Data : 1  iterations : 6  Epoch 6 --- Training Accuracy: 52.344%, Validation Accuracy: 51.562%, Validation Loss: 0.695
# Data : 1  iterations : 7  Epoch 7 --- Training Accuracy: 54.688%, Validation Accuracy: 64.062%, Validation Loss: 0.727
# Data : 1  iterations : 8  Epoch 8 --- Training Accuracy: 48.438%, Validation Accuracy: 32.812%, Validation Loss: 0.805
# Data : 1  iterations : 9  Epoch 9 --- Training Accuracy: 47.656%, Validation Accuracy: 32.812%, Validation Loss: 0.769
# Data : 1  iterations : 10  Epoch 10 --- Training Accuracy: 60.156%, Validation Accuracy: 31.250%, Validation Loss: 0.760
# Data : 1  iterations : 11  Epoch 11 --- Training Accuracy: 44.531%, Validation Accuracy: 29.688%, Validation Loss: 0.745
# Data : 1  iterations : 12  Epoch 12 --- Training Accuracy: 46.094%, Validation Accuracy: 37.500%, Validation Loss: 0.715
# Data : 1  iterations : 13  Epoch 13 --- Training Accuracy: 50.781%, Validation Accuracy: 59.375%, Validation Loss: 0.767
# Data : 1  iterations : 14  Epoch 14 --- Training Accuracy: 55.469%, Validation Accuracy: 54.688%, Validation Loss: 0.685
# Data : 1  iterations : 15  Epoch 0 --- Training Accuracy: 49.219%, Validation Accuracy: 59.375%, Validation Loss: 0.676
# Data : 1  iterations : 16  Epoch 1 --- Training Accuracy: 48.438%, Validation Accuracy: 60.938%, Validation Loss: 0.665
# Data : 1  iterations : 17  Epoch 2 --- Training Accuracy: 52.344%, Validation Accuracy: 54.688%, Validation Loss: 0.674
# Data : 1  iterations : 18  Epoch 3 --- Training Accuracy: 45.312%, Validation Accuracy: 51.562%, Validation Loss: 0.649
# Data : 1  iterations : 19  Epoch 4 --- Training Accuracy: 48.438%, Validation Accuracy: 53.125%, Validation Loss: 0.695
# Data : 1  iterations : 20  Epoch 5 --- Training Accuracy: 46.875%, Validation Accuracy: 67.188%, Validation Loss: 0.710
# Data : 1  iterations : 21  Epoch 6 --- Training Accuracy: 58.594%, Validation Accuracy: 46.875%, Validation Loss: 0.697
# Data : 1  iterations : 22  Epoch 7 --- Training Accuracy: 56.250%, Validation Accuracy: 54.688%, Validation Loss: 0.682
# Data : 1  iterations : 23  Epoch 8 --- Training Accuracy: 56.250%, Validation Accuracy: 45.312%, Validation Loss: 0.720
# Data : 1  iterations : 24  Epoch 9 --- Training Accuracy: 45.312%, Validation Accuracy: 50.000%, Validation Loss: 0.729
# Data : 1  iterations : 25  Epoch 10 --- Training Accuracy: 46.875%, Validation Accuracy: 59.375%, Validation Loss: 0.718
# Data : 1  iterations : 26  Epoch 11 --- Training Accuracy: 47.656%, Validation Accuracy: 50.000%, Validation Loss: 0.716
# Data : 1  iterations : 27  Epoch 12 --- Training Accuracy: 53.125%, Validation Accuracy: 54.688%, Validation Loss: 0.742
# Data : 1  iterations : 28  Epoch 13 --- Training Accuracy: 53.125%, Validation Accuracy: 42.188%, Validation Loss: 0.750
# Data : 1  iterations : 29  Epoch 14 --- Training Accuracy: 50.000%, Validation Accuracy: 51.562%, Validation Loss: 0.717
# Data : 1  iterations : 30  Epoch 0 --- Training Accuracy: 56.250%, Validation Accuracy: 42.188%, Validation Loss: 0.697
# Data : 1  iterations : 31  Epoch 1 --- Training Accuracy: 54.688%, Validation Accuracy: 59.375%, Validation Loss: 0.707
# Data : 1  iterations : 32  Epoch 2 --- Training Accuracy: 46.875%, Validation Accuracy: 56.250%, Validation Loss: 0.690
# Data : 1  iterations : 33  Epoch 3 --- Training Accuracy: 55.469%, Validation Accuracy: 57.812%, Validation Loss: 0.698
# Data : 1  iterations : 34  Epoch 4 --- Training Accuracy: 53.906%, Validation Accuracy: 62.500%, Validation Loss: 0.671
# Data : 1  iterations : 35  Epoch 5 --- Training Accuracy: 59.375%, Validation Accuracy: 64.062%, Validation Loss: 0.663
# Data : 1  iterations : 36  Epoch 6 --- Training Accuracy: 61.719%, Validation Accuracy: 57.812%, Validation Loss: 0.647
# Data : 1  iterations : 37  Epoch 7 --- Training Accuracy: 54.688%, Validation Accuracy: 64.062%, Validation Loss: 0.685
# Data : 1  iterations : 38  Epoch 8 --- Training Accuracy: 54.688%, Validation Accuracy: 64.062%, Validation Loss: 0.639
# Data : 1  iterations : 39  Epoch 9 --- Training Accuracy: 64.844%, Validation Accuracy: 70.312%, Validation Loss: 0.651
# Data : 1  iterations : 40  Epoch 10 --- Training Accuracy: 60.938%, Validation Accuracy: 64.062%, Validation Loss: 0.685
# Data : 1  iterations : 41  Epoch 11 --- Training Accuracy: 54.688%, Validation Accuracy: 48.438%, Validation Loss: 0.696
# Data : 1  iterations : 42  Epoch 12 --- Training Accuracy: 61.719%, Validation Accuracy: 54.688%, Validation Loss: 0.695
# Data : 1  iterations : 43  Epoch 13 --- Training Accuracy: 56.250%, Validation Accuracy: 60.938%, Validation Loss: 0.676
# Data : 1  iterations : 44  Epoch 14 --- Training Accuracy: 58.594%, Validation Accuracy: 57.812%, Validation Loss: 0.693
# Data : 1  iterations : 45  Epoch 0 --- Training Accuracy: 60.156%, Validation Accuracy: 54.688%, Validation Loss: 0.688
# Data : 1  iterations : 46  Epoch 1 --- Training Accuracy: 57.812%, Validation Accuracy: 54.688%, Validation Loss: 0.721
# Data : 1  iterations : 47  Epoch 2 --- Training Accuracy: 60.938%, Validation Accuracy: 42.188%, Validation Loss: 0.699
# Data : 1  iterations : 48  Epoch 3 --- Training Accuracy: 62.500%, Validation Accuracy: 60.938%, Validation Loss: 0.681
# Data : 1  iterations : 49  Epoch 4 --- Training Accuracy: 64.062%, Validation Accuracy: 62.500%, Validation Loss: 0.654
# Data : 1  iterations : 50  Epoch 5 --- Training Accuracy: 61.719%, Validation Accuracy: 73.438%, Validation Loss: 0.619 *
# Data : 1  iterations : 51  Epoch 6 --- Training Accuracy: 62.500%, Validation Accuracy: 65.625%, Validation Loss: 0.621
# Data : 1  iterations : 52  Epoch 7 --- Training Accuracy: 53.125%, Validation Accuracy: 75.000%, Validation Loss: 0.637
# Data : 1  iterations : 53  Epoch 8 --- Training Accuracy: 62.500%, Validation Accuracy: 65.625%, Validation Loss: 0.596 *
# Data : 1  iterations : 54  Epoch 9 --- Training Accuracy: 64.844%, Validation Accuracy: 73.438%, Validation Loss: 0.608
# Data : 1  iterations : 55  Epoch 10 --- Training Accuracy: 62.500%, Validation Accuracy: 68.750%, Validation Loss: 0.651
# Data : 1  iterations : 56  Epoch 11 --- Training Accuracy: 65.625%, Validation Accuracy: 59.375%, Validation Loss: 0.650
# Data : 1  iterations : 57  Epoch 12 --- Training Accuracy: 61.719%, Validation Accuracy: 70.312%, Validation Loss: 0.643
# Data : 1  iterations : 58  Epoch 13 --- Training Accuracy: 63.281%, Validation Accuracy: 60.938%, Validation Loss: 0.690
# Data : 1  iterations : 59  Epoch 14 --- Training Accuracy: 71.875%, Validation Accuracy: 46.875%, Validation Loss: 0.710
# Data : 1  iterations : 60  Epoch 0 --- Training Accuracy: 60.938%, Validation Accuracy: 68.750%, Validation Loss: 0.665
# Data : 1  iterations : 61  Epoch 1 --- Training Accuracy: 69.531%, Validation Accuracy: 70.312%, Validation Loss: 0.622
# Data : 1  iterations : 62  Epoch 2 --- Training Accuracy: 66.406%, Validation Accuracy: 70.312%, Validation Loss: 0.588 *
# Data : 1  iterations : 63  Epoch 3 --- Training Accuracy: 66.406%, Validation Accuracy: 65.625%, Validation Loss: 0.619
# Data : 1  iterations : 64  Epoch 4 --- Training Accuracy: 68.750%, Validation Accuracy: 76.562%, Validation Loss: 0.588
# Data : 1  iterations : 65  Epoch 5 --- Training Accuracy: 70.312%, Validation Accuracy: 70.312%, Validation Loss: 0.561 *
# Data : 1  iterations : 66  Epoch 6 --- Training Accuracy: 65.625%, Validation Accuracy: 73.438%, Validation Loss: 0.574
# Data : 1  iterations : 67  Epoch 7 --- Training Accuracy: 68.750%, Validation Accuracy: 71.875%, Validation Loss: 0.610
# Data : 1  iterations : 68  Epoch 8 --- Training Accuracy: 64.844%, Validation Accuracy: 62.500%, Validation Loss: 0.631
# Data : 1  iterations : 69  Epoch 9 --- Training Accuracy: 57.812%, Validation Accuracy: 71.875%, Validation Loss: 0.652
# Data : 1  iterations : 70  Epoch 10 --- Training Accuracy: 64.062%, Validation Accuracy: 59.375%, Validation Loss: 0.693
# Data : 1  iterations : 71  Epoch 11 --- Training Accuracy: 65.625%, Validation Accuracy: 53.125%, Validation Loss: 0.718
# Data : 1  iterations : 72  Epoch 12 --- Training Accuracy: 69.531%, Validation Accuracy: 67.188%, Validation Loss: 0.642
# Data : 1  iterations : 73  Epoch 13 --- Training Accuracy: 74.219%, Validation Accuracy: 73.438%, Validation Loss: 0.570
# Data : 1  iterations : 74  Epoch 14 --- Training Accuracy: 69.531%, Validation Accuracy: 82.812%, Validation Loss: 0.531 *
# Data : 1  iterations : 75  Epoch 0 --- Training Accuracy: 70.312%, Validation Accuracy: 70.312%, Validation Loss: 0.581
# Data : 1  iterations : 76  Epoch 1 --- Training Accuracy: 68.750%, Validation Accuracy: 70.312%, Validation Loss: 0.581
# Data : 1  iterations : 77  Epoch 2 --- Training Accuracy: 66.406%, Validation Accuracy: 81.250%, Validation Loss: 0.515 *
# Data : 1  iterations : 78  Epoch 3 --- Training Accuracy: 75.781%, Validation Accuracy: 78.125%, Validation Loss: 0.523
# Data : 1  iterations : 79  Epoch 4 --- Training Accuracy: 75.781%, Validation Accuracy: 73.438%, Validation Loss: 0.559
# Data : 1  iterations : 80  Epoch 5 --- Training Accuracy: 69.531%, Validation Accuracy: 75.000%, Validation Loss: 0.584
# Data : 1  iterations : 81  Epoch 6 --- Training Accuracy: 74.219%, Validation Accuracy: 73.438%, Validation Loss: 0.651
# Data : 1  iterations : 82  Epoch 7 --- Training Accuracy: 70.312%, Validation Accuracy: 54.688%, Validation Loss: 0.739
# Data : 1  iterations : 83  Epoch 8 --- Training Accuracy: 61.719%, Validation Accuracy: 50.000%, Validation Loss: 0.754
# Data : 1  iterations : 84  Epoch 9 --- Training Accuracy: 64.062%, Validation Accuracy: 62.500%, Validation Loss: 0.698
# Data : 1  iterations : 85  Epoch 10 --- Training Accuracy: 65.625%, Validation Accuracy: 75.000%, Validation Loss: 0.568
# Data : 1  iterations : 86  Epoch 11 --- Training Accuracy: 70.312%, Validation Accuracy: 79.688%, Validation Loss: 0.534
# Data : 1  iterations : 87  Epoch 12 --- Training Accuracy: 73.438%, Validation Accuracy: 70.312%, Validation Loss: 0.571
# Data : 1  iterations : 88  Epoch 13 --- Training Accuracy: 67.969%, Validation Accuracy: 78.125%, Validation Loss: 0.528
# Data : 1  iterations : 89  Epoch 14 --- Training Accuracy: 75.000%, Validation Accuracy: 78.125%, Validation Loss: 0.475 *
# Data : 1  iterations : 90  Epoch 0 --- Training Accuracy: 72.656%, Validation Accuracy: 76.562%, Validation Loss: 0.509
# Data : 1  iterations : 91  Epoch 1 --- Training Accuracy: 76.562%, Validation Accuracy: 76.562%, Validation Loss: 0.536
# Data : 1  iterations : 92  Epoch 2 --- Training Accuracy: 79.688%, Validation Accuracy: 79.688%, Validation Loss: 0.497
# Data : 1  iterations : 93  Epoch 3 --- Training Accuracy: 73.438%, Validation Accuracy: 81.250%, Validation Loss: 0.508
# Data : 1  iterations : 94  Epoch 4 --- Training Accuracy: 71.875%, Validation Accuracy: 71.875%, Validation Loss: 0.684
# Data : 1  iterations : 95  Epoch 5 --- Training Accuracy: 78.906%, Validation Accuracy: 57.812%, Validation Loss: 0.708
# Data : 1  iterations : 96  Epoch 6 --- Training Accuracy: 75.781%, Validation Accuracy: 64.062%, Validation Loss: 0.696
# Data : 1  iterations : 97  Epoch 7 --- Training Accuracy: 67.188%, Validation Accuracy: 70.312%, Validation Loss: 0.628
# Data : 1  iterations : 98  Epoch 8 --- Training Accuracy: 70.312%, Validation Accuracy: 78.125%, Validation Loss: 0.582
# Data : 1  iterations : 99  Epoch 9 --- Training Accuracy: 68.750%, Validation Accuracy: 65.625%, Validation Loss: 0.603
# Data : 1  iterations : 100  Epoch 10 --- Training Accuracy: 78.125%, Validation Accuracy: 76.562%, Validation Loss: 0.529
# Reading training images
# Loading vegetation files (Index: 0)
# Loading notVegetation files (Index: 1)
# Data : 2  iterations : 1  Epoch 11 --- Training Accuracy: 66.406%, Validation Accuracy: 85.938%, Validation Loss: 0.442 *
# Data : 2  iterations : 2  Epoch 12 --- Training Accuracy: 86.719%, Validation Accuracy: 76.562%, Validation Loss: 0.519
# Data : 2  iterations : 3  Epoch 13 --- Training Accuracy: 78.906%, Validation Accuracy: 82.812%, Validation Loss: 0.492
# Data : 2  iterations : 4  Epoch 14 --- Training Accuracy: 73.438%, Validation Accuracy: 73.438%, Validation Loss: 0.547
# Data : 2  iterations : 5  Epoch 0 --- Training Accuracy: 72.656%, Validation Accuracy: 87.500%, Validation Loss: 0.457
# Data : 2  iterations : 6  Epoch 1 --- Training Accuracy: 82.031%, Validation Accuracy: 85.938%, Validation Loss: 0.386 *
# Data : 2  iterations : 7  Epoch 2 --- Training Accuracy: 78.906%, Validation Accuracy: 82.812%, Validation Loss: 0.492
# Data : 2  iterations : 8  Epoch 3 --- Training Accuracy: 72.656%, Validation Accuracy: 75.000%, Validation Loss: 0.514
# Data : 2  iterations : 9  Epoch 4 --- Training Accuracy: 79.688%, Validation Accuracy: 81.250%, Validation Loss: 0.496
# Data : 2  iterations : 10  Epoch 5 --- Training Accuracy: 76.562%, Validation Accuracy: 76.562%, Validation Loss: 0.538
# Data : 2  iterations : 11  Epoch 6 --- Training Accuracy: 81.250%, Validation Accuracy: 78.125%, Validation Loss: 0.465
# Data : 2  iterations : 12  Epoch 7 --- Training Accuracy: 70.312%, Validation Accuracy: 75.000%, Validation Loss: 0.598
# Data : 2  iterations : 13  Epoch 8 --- Training Accuracy: 82.031%, Validation Accuracy: 82.812%, Validation Loss: 0.467
# Data : 2  iterations : 14  Epoch 9 --- Training Accuracy: 72.656%, Validation Accuracy: 79.688%, Validation Loss: 0.520
# Data : 2  iterations : 15  Epoch 10 --- Training Accuracy: 71.094%, Validation Accuracy: 75.000%, Validation Loss: 0.591
# Data : 2  iterations : 16  Epoch 11 --- Training Accuracy: 89.062%, Validation Accuracy: 73.438%, Validation Loss: 0.540
# Data : 2  iterations : 17  Epoch 12 --- Training Accuracy: 82.812%, Validation Accuracy: 84.375%, Validation Loss: 0.407
# Data : 2  iterations : 18  Epoch 13 --- Training Accuracy: 78.906%, Validation Accuracy: 92.188%, Validation Loss: 0.344 *
# Data : 2  iterations : 19  Epoch 14 --- Training Accuracy: 81.250%, Validation Accuracy: 85.938%, Validation Loss: 0.404
# Data : 2  iterations : 20  Epoch 0 --- Training Accuracy: 85.938%, Validation Accuracy: 84.375%, Validation Loss: 0.387
# Data : 2  iterations : 21  Epoch 1 --- Training Accuracy: 82.031%, Validation Accuracy: 82.812%, Validation Loss: 0.417
# Data : 2  iterations : 22  Epoch 2 --- Training Accuracy: 82.812%, Validation Accuracy: 81.250%, Validation Loss: 0.510
# Data : 2  iterations : 23  Epoch 3 --- Training Accuracy: 80.469%, Validation Accuracy: 81.250%, Validation Loss: 0.461
# Data : 2  iterations : 24  Epoch 4 --- Training Accuracy: 80.469%, Validation Accuracy: 78.125%, Validation Loss: 0.571
# Data : 2  iterations : 25  Epoch 5 --- Training Accuracy: 84.375%, Validation Accuracy: 84.375%, Validation Loss: 0.428
# Data : 2  iterations : 26  Epoch 6 --- Training Accuracy: 78.906%, Validation Accuracy: 82.812%, Validation Loss: 0.470
# Data : 2  iterations : 27  Epoch 7 --- Training Accuracy: 82.812%, Validation Accuracy: 85.938%, Validation Loss: 0.434
# Data : 2  iterations : 28  Epoch 8 --- Training Accuracy: 75.000%, Validation Accuracy: 82.812%, Validation Loss: 0.414
# Data : 2  iterations : 29  Epoch 9 --- Training Accuracy: 75.000%, Validation Accuracy: 89.062%, Validation Loss: 0.335 *
# Data : 2  iterations : 30  Epoch 10 --- Training Accuracy: 92.969%, Validation Accuracy: 89.062%, Validation Loss: 0.327 *
# Data : 2  iterations : 31  Epoch 11 --- Training Accuracy: 87.500%, Validation Accuracy: 84.375%, Validation Loss: 0.387
# Data : 2  iterations : 32  Epoch 12 --- Training Accuracy: 85.938%, Validation Accuracy: 79.688%, Validation Loss: 0.443
# Data : 2  iterations : 33  Epoch 13 --- Training Accuracy: 84.375%, Validation Accuracy: 89.062%, Validation Loss: 0.389
# Data : 2  iterations : 34  Epoch 14 --- Training Accuracy: 88.281%, Validation Accuracy: 78.125%, Validation Loss: 0.377
# Data : 2  iterations : 35  Epoch 0 --- Training Accuracy: 83.594%, Validation Accuracy: 85.938%, Validation Loss: 0.371
# Data : 2  iterations : 36  Epoch 1 --- Training Accuracy: 86.719%, Validation Accuracy: 75.000%, Validation Loss: 0.450
# Data : 2  iterations : 37  Epoch 2 --- Training Accuracy: 84.375%, Validation Accuracy: 85.938%, Validation Loss: 0.402
# Data : 2  iterations : 38  Epoch 3 --- Training Accuracy: 88.281%, Validation Accuracy: 84.375%, Validation Loss: 0.335
# Data : 2  iterations : 39  Epoch 4 --- Training Accuracy: 82.812%, Validation Accuracy: 87.500%, Validation Loss: 0.284 *
# Data : 2  iterations : 40  Epoch 5 --- Training Accuracy: 86.719%, Validation Accuracy: 84.375%, Validation Loss: 0.319
# Data : 2  iterations : 41  Epoch 6 --- Training Accuracy: 89.062%, Validation Accuracy: 89.062%, Validation Loss: 0.287
# Data : 2  iterations : 42  Epoch 7 --- Training Accuracy: 87.500%, Validation Accuracy: 81.250%, Validation Loss: 0.345
# Data : 2  iterations : 43  Epoch 8 --- Training Accuracy: 87.500%, Validation Accuracy: 85.938%, Validation Loss: 0.414
# Data : 2  iterations : 44  Epoch 9 --- Training Accuracy: 94.531%, Validation Accuracy: 89.062%, Validation Loss: 0.280 *
# Data : 2  iterations : 45  Epoch 10 --- Training Accuracy: 85.156%, Validation Accuracy: 89.062%, Validation Loss: 0.277 *
# Data : 2  iterations : 46  Epoch 11 --- Training Accuracy: 87.500%, Validation Accuracy: 87.500%, Validation Loss: 0.259 *
# Data : 2  iterations : 47  Epoch 12 --- Training Accuracy: 89.844%, Validation Accuracy: 89.062%, Validation Loss: 0.346
# Data : 2  iterations : 48  Epoch 13 --- Training Accuracy: 87.500%, Validation Accuracy: 78.125%, Validation Loss: 0.486
# Data : 2  iterations : 49  Epoch 14 --- Training Accuracy: 90.625%, Validation Accuracy: 93.750%, Validation Loss: 0.295
# Data : 2  iterations : 50  Epoch 0 --- Training Accuracy: 87.500%, Validation Accuracy: 87.500%, Validation Loss: 0.314
# Data : 2  iterations : 51  Epoch 1 --- Training Accuracy: 91.406%, Validation Accuracy: 92.188%, Validation Loss: 0.279
# Data : 2  iterations : 52  Epoch 2 --- Training Accuracy: 92.188%, Validation Accuracy: 89.062%, Validation Loss: 0.251 *
# Data : 2  iterations : 53  Epoch 3 --- Training Accuracy: 92.969%, Validation Accuracy: 92.188%, Validation Loss: 0.247 *
# Data : 2  iterations : 54  Epoch 4 --- Training Accuracy: 92.188%, Validation Accuracy: 89.062%, Validation Loss: 0.292
# Data : 2  iterations : 55  Epoch 5 --- Training Accuracy: 91.406%, Validation Accuracy: 92.188%, Validation Loss: 0.256
# Data : 2  iterations : 56  Epoch 6 --- Training Accuracy: 91.406%, Validation Accuracy: 89.062%, Validation Loss: 0.316
# Data : 2  iterations : 57  Epoch 7 --- Training Accuracy: 85.938%, Validation Accuracy: 87.500%, Validation Loss: 0.328
# Data : 2  iterations : 58  Epoch 8 --- Training Accuracy: 96.094%, Validation Accuracy: 92.188%, Validation Loss: 0.233 *
# Data : 2  iterations : 59  Epoch 9 --- Training Accuracy: 89.062%, Validation Accuracy: 89.062%, Validation Loss: 0.332
# Data : 2  iterations : 60  Epoch 10 --- Training Accuracy: 92.188%, Validation Accuracy: 87.500%, Validation Loss: 0.362
# Data : 2  iterations : 61  Epoch 11 --- Training Accuracy: 90.625%, Validation Accuracy: 92.188%, Validation Loss: 0.259
# Data : 2  iterations : 62  Epoch 12 --- Training Accuracy: 85.938%, Validation Accuracy: 90.625%, Validation Loss: 0.282
# Data : 2  iterations : 63  Epoch 13 --- Training Accuracy: 90.625%, Validation Accuracy: 90.625%, Validation Loss: 0.289
# Data : 2  iterations : 64  Epoch 14 --- Training Accuracy: 90.625%, Validation Accuracy: 92.188%, Validation Loss: 0.229 *
# Data : 2  iterations : 65  Epoch 0 --- Training Accuracy: 94.531%, Validation Accuracy: 89.062%, Validation Loss: 0.223 *
# Data : 2  iterations : 66  Epoch 1 --- Training Accuracy: 91.406%, Validation Accuracy: 89.062%, Validation Loss: 0.231
# Data : 2  iterations : 67  Epoch 2 --- Training Accuracy: 96.094%, Validation Accuracy: 90.625%, Validation Loss: 0.229
# Data : 2  iterations : 68  Epoch 3 --- Training Accuracy: 92.188%, Validation Accuracy: 90.625%, Validation Loss: 0.263
# Data : 2  iterations : 69  Epoch 4 --- Training Accuracy: 92.969%, Validation Accuracy: 93.750%, Validation Loss: 0.247
# Data : 2  iterations : 70  Epoch 5 --- Training Accuracy: 90.625%, Validation Accuracy: 90.625%, Validation Loss: 0.240
# Data : 2  iterations : 71  Epoch 6 --- Training Accuracy: 87.500%, Validation Accuracy: 89.062%, Validation Loss: 0.331
# Data : 2  iterations : 72  Epoch 7 --- Training Accuracy: 92.969%, Validation Accuracy: 87.500%, Validation Loss: 0.340
# Data : 2  iterations : 73  Epoch 8 --- Training Accuracy: 89.062%, Validation Accuracy: 92.188%, Validation Loss: 0.182 *
# Data : 2  iterations : 74  Epoch 9 --- Training Accuracy: 93.750%, Validation Accuracy: 90.625%, Validation Loss: 0.228
# Data : 2  iterations : 75  Epoch 10 --- Training Accuracy: 89.844%, Validation Accuracy: 87.500%, Validation Loss: 0.319
# Data : 2  iterations : 76  Epoch 11 --- Training Accuracy: 89.062%, Validation Accuracy: 90.625%, Validation Loss: 0.297
# Data : 2  iterations : 77  Epoch 12 --- Training Accuracy: 86.719%, Validation Accuracy: 90.625%, Validation Loss: 0.264
# Data : 2  iterations : 78  Epoch 13 --- Training Accuracy: 89.062%, Validation Accuracy: 92.188%, Validation Loss: 0.225
# Data : 2  iterations : 79  Epoch 14 --- Training Accuracy: 92.188%, Validation Accuracy: 93.750%, Validation Loss: 0.212
# Data : 2  iterations : 80  Epoch 0 --- Training Accuracy: 89.844%, Validation Accuracy: 92.188%, Validation Loss: 0.254
# Data : 2  iterations : 81  Epoch 1 --- Training Accuracy: 94.531%, Validation Accuracy: 92.188%, Validation Loss: 0.253
# Data : 2  iterations : 82  Epoch 2 --- Training Accuracy: 92.188%, Validation Accuracy: 93.750%, Validation Loss: 0.210
# Data : 2  iterations : 83  Epoch 3 --- Training Accuracy: 91.406%, Validation Accuracy: 90.625%, Validation Loss: 0.341
# Data : 2  iterations : 84  Epoch 4 --- Training Accuracy: 90.625%, Validation Accuracy: 81.250%, Validation Loss: 0.352
# Data : 2  iterations : 85  Epoch 5 --- Training Accuracy: 88.281%, Validation Accuracy: 89.062%, Validation Loss: 0.268
# Data : 2  iterations : 86  Epoch 6 --- Training Accuracy: 95.312%, Validation Accuracy: 90.625%, Validation Loss: 0.242
# Data : 2  iterations : 87  Epoch 7 --- Training Accuracy: 90.625%, Validation Accuracy: 93.750%, Validation Loss: 0.235
# Data : 2  iterations : 88  Epoch 8 --- Training Accuracy: 94.531%, Validation Accuracy: 95.312%, Validation Loss: 0.203
# Data : 2  iterations : 89  Epoch 9 --- Training Accuracy: 89.844%, Validation Accuracy: 95.312%, Validation Loss: 0.230
# Data : 2  iterations : 90  Epoch 10 --- Training Accuracy: 88.281%, Validation Accuracy: 89.062%, Validation Loss: 0.249
# Data : 2  iterations : 91  Epoch 11 --- Training Accuracy: 91.406%, Validation Accuracy: 93.750%, Validation Loss: 0.269
# Data : 2  iterations : 92  Epoch 12 --- Training Accuracy: 92.969%, Validation Accuracy: 87.500%, Validation Loss: 0.291
# Data : 2  iterations : 93  Epoch 13 --- Training Accuracy: 92.969%, Validation Accuracy: 90.625%, Validation Loss: 0.264
# Data : 2  iterations : 94  Epoch 14 --- Training Accuracy: 92.969%, Validation Accuracy: 93.750%, Validation Loss: 0.171 *
# Data : 2  iterations : 95  Epoch 0 --- Training Accuracy: 96.094%, Validation Accuracy: 89.062%, Validation Loss: 0.271
# Data : 2  iterations : 96  Epoch 1 --- Training Accuracy: 90.625%, Validation Accuracy: 90.625%, Validation Loss: 0.318
# Data : 2  iterations : 97  Epoch 2 --- Training Accuracy: 94.531%, Validation Accuracy: 92.188%, Validation Loss: 0.207
# Data : 2  iterations : 98  Epoch 3 --- Training Accuracy: 90.625%, Validation Accuracy: 90.625%, Validation Loss: 0.211
# Data : 2  iterations : 99  Epoch 4 --- Training Accuracy: 89.844%, Validation Accuracy: 87.500%, Validation Loss: 0.321
# Data : 2  iterations : 100  Epoch 5 --- Training Accuracy: 93.750%, Validation Accuracy: 92.188%, Validation Loss: 0.243
# Reading training images
# Loading vegetation files (Index: 0)
# Loading notVegetation files (Index: 1)
# Data : 3  iterations : 1  Epoch 6 --- Training Accuracy: 87.500%, Validation Accuracy: 90.625%, Validation Loss: 0.224
# Data : 3  iterations : 2  Epoch 7 --- Training Accuracy: 89.844%, Validation Accuracy: 95.312%, Validation Loss: 0.144 *
# Data : 3  iterations : 3  Epoch 8 --- Training Accuracy: 92.969%, Validation Accuracy: 90.625%, Validation Loss: 0.307
# Data : 3  iterations : 4  Epoch 9 --- Training Accuracy: 93.750%, Validation Accuracy: 95.312%, Validation Loss: 0.217
# Data : 3  iterations : 5  Epoch 10 --- Training Accuracy: 93.750%, Validation Accuracy: 92.188%, Validation Loss: 0.214
# Data : 3  iterations : 6  Epoch 11 --- Training Accuracy: 85.156%, Validation Accuracy: 89.062%, Validation Loss: 0.333
# Data : 3  iterations : 7  Epoch 12 --- Training Accuracy: 89.062%, Validation Accuracy: 89.062%, Validation Loss: 0.243
# Data : 3  iterations : 8  Epoch 13 --- Training Accuracy: 93.750%, Validation Accuracy: 98.438%, Validation Loss: 0.150
# Data : 3  iterations : 9  Epoch 14 --- Training Accuracy: 95.312%, Validation Accuracy: 96.875%, Validation Loss: 0.170
# Data : 3  iterations : 10  Epoch 0 --- Training Accuracy: 90.625%, Validation Accuracy: 90.625%, Validation Loss: 0.296
# Data : 3  iterations : 11  Epoch 1 --- Training Accuracy: 92.969%, Validation Accuracy: 92.188%, Validation Loss: 0.198
# Data : 3  iterations : 12  Epoch 2 --- Training Accuracy: 88.281%, Validation Accuracy: 92.188%, Validation Loss: 0.188
# Data : 3  iterations : 13  Epoch 3 --- Training Accuracy: 92.188%, Validation Accuracy: 87.500%, Validation Loss: 0.220
# Data : 3  iterations : 14  Epoch 4 --- Training Accuracy: 92.188%, Validation Accuracy: 96.875%, Validation Loss: 0.211
# Data : 3  iterations : 15  Epoch 5 --- Training Accuracy: 89.844%, Validation Accuracy: 89.062%, Validation Loss: 0.372
# Data : 3  iterations : 16  Epoch 6 --- Training Accuracy: 88.281%, Validation Accuracy: 89.062%, Validation Loss: 0.246
# Data : 3  iterations : 17  Epoch 7 --- Training Accuracy: 92.969%, Validation Accuracy: 90.625%, Validation Loss: 0.219
# Data : 3  iterations : 18  Epoch 8 --- Training Accuracy: 92.188%, Validation Accuracy: 93.750%, Validation Loss: 0.197
# Data : 3  iterations : 19  Epoch 9 --- Training Accuracy: 92.188%, Validation Accuracy: 93.750%, Validation Loss: 0.177
# Data : 3  iterations : 20  Epoch 10 --- Training Accuracy: 91.406%, Validation Accuracy: 96.875%, Validation Loss: 0.135 *
# Data : 3  iterations : 21  Epoch 11 --- Training Accuracy: 91.406%, Validation Accuracy: 89.062%, Validation Loss: 0.222
# Data : 3  iterations : 22  Epoch 12 --- Training Accuracy: 91.406%, Validation Accuracy: 89.062%, Validation Loss: 0.335
# Data : 3  iterations : 23  Epoch 13 --- Training Accuracy: 94.531%, Validation Accuracy: 93.750%, Validation Loss: 0.285
# Data : 3  iterations : 24  Epoch 14 --- Training Accuracy: 90.625%, Validation Accuracy: 92.188%, Validation Loss: 0.201
# Data : 3  iterations : 25  Epoch 0 --- Training Accuracy: 93.750%, Validation Accuracy: 90.625%, Validation Loss: 0.233
# Data : 3  iterations : 26  Epoch 1 --- Training Accuracy: 92.188%, Validation Accuracy: 95.312%, Validation Loss: 0.155
# Data : 3  iterations : 27  Epoch 2 --- Training Accuracy: 88.281%, Validation Accuracy: 93.750%, Validation Loss: 0.277
# Data : 3  iterations : 28  Epoch 3 --- Training Accuracy: 90.625%, Validation Accuracy: 92.188%, Validation Loss: 0.233
# Data : 3  iterations : 29  Epoch 4 --- Training Accuracy: 91.406%, Validation Accuracy: 92.188%, Validation Loss: 0.192
# Data : 3  iterations : 30  Epoch 5 --- Training Accuracy: 90.625%, Validation Accuracy: 93.750%, Validation Loss: 0.266
# Data : 3  iterations : 31  Epoch 6 --- Training Accuracy: 93.750%, Validation Accuracy: 95.312%, Validation Loss: 0.158
# Data : 3  iterations : 32  Epoch 7 --- Training Accuracy: 91.406%, Validation Accuracy: 95.312%, Validation Loss: 0.136
# Data : 3  iterations : 33  Epoch 8 --- Training Accuracy: 92.969%, Validation Accuracy: 96.875%, Validation Loss: 0.171
# Data : 3  iterations : 34  Epoch 9 --- Training Accuracy: 91.406%, Validation Accuracy: 92.188%, Validation Loss: 0.261
# Data : 3  iterations : 35  Epoch 10 --- Training Accuracy: 91.406%, Validation Accuracy: 93.750%, Validation Loss: 0.228
# Data : 3  iterations : 36  Epoch 11 --- Training Accuracy: 96.094%, Validation Accuracy: 90.625%, Validation Loss: 0.231
# Data : 3  iterations : 37  Epoch 12 --- Training Accuracy: 95.312%, Validation Accuracy: 87.500%, Validation Loss: 0.223
# Data : 3  iterations : 38  Epoch 13 --- Training Accuracy: 90.625%, Validation Accuracy: 93.750%, Validation Loss: 0.156
# Data : 3  iterations : 39  Epoch 14 --- Training Accuracy: 93.750%, Validation Accuracy: 93.750%, Validation Loss: 0.281
# Data : 3  iterations : 40  Epoch 0 --- Training Accuracy: 89.062%, Validation Accuracy: 90.625%, Validation Loss: 0.235
# Data : 3  iterations : 41  Epoch 1 --- Training Accuracy: 90.625%, Validation Accuracy: 95.312%, Validation Loss: 0.183
# Data : 3  iterations : 42  Epoch 2 --- Training Accuracy: 94.531%, Validation Accuracy: 95.312%, Validation Loss: 0.228
# Data : 3  iterations : 43  Epoch 3 --- Training Accuracy: 90.625%, Validation Accuracy: 95.312%, Validation Loss: 0.146
# Data : 3  iterations : 44  Epoch 4 --- Training Accuracy: 92.188%, Validation Accuracy: 96.875%, Validation Loss: 0.111 *
# Data : 3  iterations : 45  Epoch 5 --- Training Accuracy: 92.969%, Validation Accuracy: 98.438%, Validation Loss: 0.138
# Data : 3  iterations : 46  Epoch 6 --- Training Accuracy: 91.406%, Validation Accuracy: 85.938%, Validation Loss: 0.250
# Data : 3  iterations : 47  Epoch 7 --- Training Accuracy: 93.750%, Validation Accuracy: 93.750%, Validation Loss: 0.241
# Data : 3  iterations : 48  Epoch 8 --- Training Accuracy: 90.625%, Validation Accuracy: 90.625%, Validation Loss: 0.216
# Data : 3  iterations : 49  Epoch 9 --- Training Accuracy: 91.406%, Validation Accuracy: 90.625%, Validation Loss: 0.237
# Data : 3  iterations : 50  Epoch 10 --- Training Accuracy: 93.750%, Validation Accuracy: 96.875%, Validation Loss: 0.148
# Data : 3  iterations : 51  Epoch 11 --- Training Accuracy: 96.094%, Validation Accuracy: 95.312%, Validation Loss: 0.295
# Data : 3  iterations : 52  Epoch 12 --- Training Accuracy: 92.969%, Validation Accuracy: 89.062%, Validation Loss: 0.237
# Data : 3  iterations : 53  Epoch 13 --- Training Accuracy: 93.750%, Validation Accuracy: 90.625%, Validation Loss: 0.182
# Data : 3  iterations : 54  Epoch 14 --- Training Accuracy: 91.406%, Validation Accuracy: 95.312%, Validation Loss: 0.224
# Data : 3  iterations : 55  Epoch 0 --- Training Accuracy: 90.625%, Validation Accuracy: 96.875%, Validation Loss: 0.132
# Data : 3  iterations : 56  Epoch 1 --- Training Accuracy: 92.969%, Validation Accuracy: 96.875%, Validation Loss: 0.126
# Data : 3  iterations : 57  Epoch 2 --- Training Accuracy: 92.188%, Validation Accuracy: 92.188%, Validation Loss: 0.154
# Data : 3  iterations : 58  Epoch 3 --- Training Accuracy: 92.969%, Validation Accuracy: 90.625%, Validation Loss: 0.231
# Data : 3  iterations : 59  Epoch 4 --- Training Accuracy: 94.531%, Validation Accuracy: 93.750%, Validation Loss: 0.183
# Data : 3  iterations : 60  Epoch 5 --- Training Accuracy: 93.750%, Validation Accuracy: 93.750%, Validation Loss: 0.174
# Data : 3  iterations : 61  Epoch 6 --- Training Accuracy: 93.750%, Validation Accuracy: 93.750%, Validation Loss: 0.260
# Data : 3  iterations : 62  Epoch 7 --- Training Accuracy: 92.188%, Validation Accuracy: 96.875%, Validation Loss: 0.140
# Data : 3  iterations : 63  Epoch 8 --- Training Accuracy: 92.188%, Validation Accuracy: 92.188%, Validation Loss: 0.329
# Data : 3  iterations : 64  Epoch 9 --- Training Accuracy: 96.094%, Validation Accuracy: 87.500%, Validation Loss: 0.276
# Data : 3  iterations : 65  Epoch 10 --- Training Accuracy: 96.094%, Validation Accuracy: 92.188%, Validation Loss: 0.157
# Data : 3  iterations : 66  Epoch 11 --- Training Accuracy: 91.406%, Validation Accuracy: 95.312%, Validation Loss: 0.240
# Data : 3  iterations : 67  Epoch 12 --- Training Accuracy: 93.750%, Validation Accuracy: 93.750%, Validation Loss: 0.139
# Data : 3  iterations : 68  Epoch 13 --- Training Accuracy: 92.969%, Validation Accuracy: 95.312%, Validation Loss: 0.131
# Data : 3  iterations : 69  Epoch 14 --- Training Accuracy: 89.844%, Validation Accuracy: 93.750%, Validation Loss: 0.152
# Data : 3  iterations : 70  Epoch 0 --- Training Accuracy: 92.969%, Validation Accuracy: 92.188%, Validation Loss: 0.259
# Data : 3  iterations : 71  Epoch 1 --- Training Accuracy: 91.406%, Validation Accuracy: 93.750%, Validation Loss: 0.219
# Data : 3  iterations : 72  Epoch 2 --- Training Accuracy: 90.625%, Validation Accuracy: 90.625%, Validation Loss: 0.218
# Data : 3  iterations : 73  Epoch 3 --- Training Accuracy: 95.312%, Validation Accuracy: 92.188%, Validation Loss: 0.265
# Data : 3  iterations : 74  Epoch 4 --- Training Accuracy: 93.750%, Validation Accuracy: 95.312%, Validation Loss: 0.125
# Data : 3  iterations : 75  Epoch 5 --- Training Accuracy: 93.750%, Validation Accuracy: 93.750%, Validation Loss: 0.242
# Data : 3  iterations : 76  Epoch 6 --- Training Accuracy: 91.406%, Validation Accuracy: 89.062%, Validation Loss: 0.262
# Data : 3  iterations : 77  Epoch 7 --- Training Accuracy: 90.625%, Validation Accuracy: 92.188%, Validation Loss: 0.178
# Data : 3  iterations : 78  Epoch 8 --- Training Accuracy: 94.531%, Validation Accuracy: 93.750%, Validation Loss: 0.288
# Data : 3  iterations : 79  Epoch 9 --- Training Accuracy: 96.875%, Validation Accuracy: 95.312%, Validation Loss: 0.147
# Data : 3  iterations : 80  Epoch 10 --- Training Accuracy: 92.188%, Validation Accuracy: 95.312%, Validation Loss: 0.113
# Data : 3  iterations : 81  Epoch 11 --- Training Accuracy: 95.312%, Validation Accuracy: 98.438%, Validation Loss: 0.128
# Data : 3  iterations : 82  Epoch 12 --- Training Accuracy: 92.188%, Validation Accuracy: 89.062%, Validation Loss: 0.223
# Data : 3  iterations : 83  Epoch 13 --- Training Accuracy: 91.406%, Validation Accuracy: 93.750%, Validation Loss: 0.173
# Data : 3  iterations : 84  Epoch 14 --- Training Accuracy: 93.750%, Validation Accuracy: 89.062%, Validation Loss: 0.201
# Data : 3  iterations : 85  Epoch 0 --- Training Accuracy: 93.750%, Validation Accuracy: 92.188%, Validation Loss: 0.214
# Data : 3  iterations : 86  Epoch 1 --- Training Accuracy: 92.969%, Validation Accuracy: 95.312%, Validation Loss: 0.126
# Data : 3  iterations : 87  Epoch 2 --- Training Accuracy: 95.312%, Validation Accuracy: 93.750%, Validation Loss: 0.267
# Data : 3  iterations : 88  Epoch 3 --- Training Accuracy: 93.750%, Validation Accuracy: 92.188%, Validation Loss: 0.199
# Data : 3  iterations : 89  Epoch 4 --- Training Accuracy: 96.094%, Validation Accuracy: 96.875%, Validation Loss: 0.156
# Data : 3  iterations : 90  Epoch 5 --- Training Accuracy: 91.406%, Validation Accuracy: 95.312%, Validation Loss: 0.247
# Data : 3  iterations : 91  Epoch 6 --- Training Accuracy: 92.188%, Validation Accuracy: 92.188%, Validation Loss: 0.187
# Data : 3  iterations : 92  Epoch 7 --- Training Accuracy: 96.094%, Validation Accuracy: 95.312%, Validation Loss: 0.153
# Data : 3  iterations : 93  Epoch 8 --- Training Accuracy: 96.875%, Validation Accuracy: 93.750%, Validation Loss: 0.143
# Data : 3  iterations : 94  Epoch 9 --- Training Accuracy: 93.750%, Validation Accuracy: 89.062%, Validation Loss: 0.215
# Data : 3  iterations : 95  Epoch 10 --- Training Accuracy: 94.531%, Validation Accuracy: 93.750%, Validation Loss: 0.161
# Data : 3  iterations : 96  Epoch 11 --- Training Accuracy: 92.969%, Validation Accuracy: 92.188%, Validation Loss: 0.234
# Data : 3  iterations : 97  Epoch 12 --- Training Accuracy: 89.844%, Validation Accuracy: 92.188%, Validation Loss: 0.259
# Data : 3  iterations : 98  Epoch 13 --- Training Accuracy: 94.531%, Validation Accuracy: 96.875%, Validation Loss: 0.106 *
# Data : 3  iterations : 99  Epoch 14 --- Training Accuracy: 92.969%, Validation Accuracy: 93.750%, Validation Loss: 0.243
# Data : 3  iterations : 100  Epoch 0 --- Training Accuracy: 92.188%, Validation Accuracy: 89.062%, Validation Loss: 0.287
# End Time : 2018-05-04 14:09:06
# Time elapsed: 15:33:09

# %%
validation_performance(show_confusion_matrix=True , show_example_errors=True)
# Out:
# Accuracy on Validate-Set: 95.032% (746 / 785)
# Example errors:
# Confusion Matrix:
# [[505  25]
#  [ 14 241]]

# %% [markdown]
# ## Restore Best Variables
#
# Re-load all the variables that were saved to file during optimization.

# %%
saver.restore(sess=session, save_path=save_path)
# Out:
# INFO:tensorflow:Restoring parameters from D:\FaamruProject_kor\Model\checkpoints\_3274\20180503\best_validate_3274_randomdata

# %%
validation_performance(show_confusion_matrix=True , show_example_errors=False)
# Out:
# Accuracy on Validate-Set: 95.287% (748 / 785)
# Confusion Matrix:
# [[514  16]
#  [ 21 234]]

# %% [markdown]
# ## Visualization of Weights and Layers

# %% [markdown]
# ### plotting convolutional weights

# %%
def plot_conv_weights(weights, input_channel=0):
    w = session.run(weights)

    # Get the lowest and highest values for the weights.
    w_min = np.min(w)
    w_max = np.max(w)

    # Number of filters used in the conv. layer.
    num_filters = w.shape[3]

    # Number of grids to plot.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids)

    # Plot all the filter-weights.
    for i, ax in enumerate(axes.flat):
        if i<num_filters:
            # Get the weights for the i'th filter of the input channel.
            img = w[:, :, input_channel, i]

            # Plot image.
            ax.imshow(img, vmin=w_min, vmax=w_max, interpolation='nearest', cmap='seismic')
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# ### plotting the output of a convolutional layer

# %%
def plot_conv_layer(layer, image):
   
    image = image.reshape(img_size_flat)

    # Create a feed-dict containing just one image.
    feed_dict = {x: [image]}

    # Calculate and retrieve the output values of the layer when inputting that image.
    values = session.run(layer, feed_dict=feed_dict)

    # Number of filters used in the conv. layer.
    num_filters = values.shape[3]

    # Number of grids to plot.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids)

    # Plot the output images of all the filters.
    for i, ax in enumerate(axes.flat):
        if i<num_filters:
            # Get the output image of using the i'th filter.
            img = values[0, :, :, i]

            # Plot image.
            ax.imshow(img, interpolation='nearest', cmap='binary')
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    plt.show()

# %% [markdown]
# ### Input Testing - Images

# %% [markdown]
# function for plotting an image.

# %%
def plot_image(image):
    plt.imshow(image.reshape(img_size, img_size, num_channels),
               interpolation='nearest')
    plt.xticks([])
    plt.yticks([])

    plt.show()

# %% [markdown]
# Plot an image from the test-set which will be used as an example below.

# %%
image1 = datatest.images[70]
plot_image(image1)

# %% [markdown]
# Plot another example image from the test-set.

# %%
image2 = datatest.images[30]
plot_image(image2)

# %% [markdown]
# # Plot Images Output of Convolution Layer and Weight of each Layer

# %% [markdown]
# ### Convolution Layer 1

# %% [markdown]
# weight of Convolution Layer 1

# %%
plot_conv_weights(weights=weights_conv1)

# %% [markdown]
# output of images in convolutional layer 1

# %%
plot_conv_layer(layer=layer_conv1, image=image1)

# %% [markdown]
# ### Convolution Layer 2

# %% [markdown]
# weight of Convolution Layer 2

# %%
plot_conv_weights(weights=weights_conv2)

# %% [markdown]
# output of images in convolutional layer 1

# %%
plot_conv_layer(layer=layer_conv2, image=image1)

# %% [markdown]
# ### Convolution Layer 3

# %% [markdown]
# weight of Convolution Layer 3

# %%
plot_conv_weights(weights=weights_conv3)

# %% [markdown]
# output of images in convolutional layer 2

# %%
plot_conv_layer(layer=layer_conv3, image=image1)

# %% [markdown]
# ### Write Test Predictions to CSV

# %%
def plot_test_image(image , result):
    
    result_list = result.values.T.tolist()
   
    # Number of filters used in the conv. layer.
    num_filters = result.shape[0]

    # Number of grids to plot.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids,figsize=(15,15))
    fig.subplots_adjust(hspace=0.8, wspace=0.2)

    # Plot the output images of all the filters.
    for i, ax in enumerate(axes.flat):
        if i<num_filters:
            # Get the output image of using the i'th filter.
            img = image[i]

            # Plot image.
            ax.imshow(cv2.cvtColor(img.reshape(img_shape_wChnls), cv2.COLOR_BGR2RGB), interpolation = 'bicubic' )
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
        
        xlabel = '{0} \nTrue : {1} \nPred : Veg :{2}\n       notV : {3}'.format(result_list[0][i] , result_list[1][i] ,\
                                                                               result_list[2][i] , \
                                                                               result_list[3][i])
        ax.set_xlabel(xlabel)
        
        if i == num_filters-1 :
            break
            
            
    plt.xticks([])
    plt.yticks([])
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %%
def predictions(ims, cls , ids , write_file=True , plot_testing=False):

    images_test = ims.reshape(ims.shape[0], img_size_flat)
    num_test = len(images_test)
    
    i = 0
    ims_test_pred = list()
    images_test_pred = list()
    
    saver.restore(sess=session, save_path=save_path)

    while i < num_test:
        # The ending index for the next batch is denoted j.
        j = min(i + validate_batch_size, num_test)

        # Get the images from the test-set between index i and j.
        images = images_test[i:j, :]
        
        # Calculate the predicted class using TensorFlow.
        
        ims_test_pred = session.run(y_pred, feed_dict={x: images})
        images_test_pred.extend(ims_test_pred)
        
        # Set the start-index for the next batch to the
        # end-index of the current batch.
        i = j

        result = pd.DataFrame(images_test_pred, columns=classes)
    
    
    result['vegetation'] = pd.Series(["{0:.2f}%".format(val * 100) for val in result['vegetation']], index = result.index)
    result['notVegetation'] = pd.Series(["{0:.2f}%".format(val * 100) for val in result['notVegetation']], index = result.index)
    result.insert(loc=0, column='ids', value=ids)
    result.insert(loc=1, column='labels', value=cls)
    
    result['predicted'] = np.where(result['vegetation'] >= result['notVegetation'], 'vegetation', 'notVegetation')
    
    if plot_testing:
        plot_test_image(ims, result)
    
    pred_file = 'predictions_{}.csv'.format(time.strftime('%Y%m%d_%H%M%S', time.localtime(time.time())))
    
    if write_file:
        result.to_csv(pred_file, index=False) 
    
    result_list = result.values.T.tolist()
    result_labels = result_list[1]
    result_predicted = result_list[4]
    
    cm = confusion_matrix(y_true=result_labels,
                          y_pred=result_predicted)
    
    correct_prediction = tf.equal(result_predicted, result_labels)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    accuracy_testimages = session.run(accuracy)

    print('===== Result of prediction Images ======')   
    print(result)

    print('===== Confusion Matrix ======')
    print(cm)
    
    print('Accuracy of Test Images : {0:.2f}%'.format(accuracy_testimages*100))

# %%
predictions(datatest.images, datatest.cls, datatest.ids , write_file=True , plot_testing=False)
# Out:
# INFO:tensorflow:Restoring parameters from D:\FaamruProject_kor\Model\checkpoints\_3274\20180503\best_validate_3274_randomdata
# ===== Result of prediction Images ======
#            ids         labels vegetation notVegetation      predicted
# 0    10006.png     vegetation     99.85%         0.15%     vegetation
# 1    10007.png     vegetation     99.76%         0.24%     vegetation
# 2    10022.png     vegetation     98.64%         1.36%     vegetation
# 3    10160.png     vegetation     99.60%         0.40%     vegetation
# 4    10162.png     vegetation     99.84%         0.16%     vegetation
# 5    10217.png     vegetation     99.50%         0.50%     vegetation
# 6    10229.png     vegetation     89.52%        10.48%     vegetation
# 7    10268.png     vegetation     90.38%         9.62%     vegetation
# 8    10272.png     vegetation     90.59%         9.41%     vegetation
# 9    10280.png     vegetation     98.99%         1.01%     vegetation
# 10   10291.png     vegetation     80.06%        19.94%     vegetation
# 11   10310.png     vegetation     94.72%         5.28%     vegetation
# 12   10318.png     vegetation     97.83%         2.17%     vegetation
# 13   10358.png     vegetation     99.89%         0.11%     vegetation
# 14   10659.png     vegetation     99.88%         0.12%     vegetation
# 15   10667.png     vegetation     99.44%         0.56%     vegetation
# 16   10706.png     vegetation     97.34%         2.66%     vegetation
# 17   10806.png     vegetation     70.47%        29.53%     vegetation
# 18   10836.png     vegetation     98.95%         1.05%     vegetation
# 19   10946.png     vegetation     90.46%         9.54%     vegetation
# 20    1121.png     vegetation     93.56%         6.44%     vegetation
# 21   11330.png     vegetation     99.83%         0.17%     vegetation
# 22   11465.png     vegetation     99.96%         0.04%     vegetation
# 23   11517.png     vegetation     89.49%        10.51%     vegetation
# 24   11544.png     vegetation     99.40%         0.60%     vegetation
# 25   11555.png     vegetation     69.99%        30.01%     vegetation
# 26   11612.png     vegetation     96.73%         3.27%     vegetation
# 27   11683.png     vegetation     94.80%         5.20%     vegetation
# 28   11712.png     vegetation     99.93%         0.07%     vegetation
# 29   11732.png     vegetation     99.55%         0.45%     vegetation
# ..         ...            ...        ...           ...            ...
# 625   8712.png  notVegetation     14.57%        85.43%  notVegetation
# 626   8736.png  notVegetation     25.97%        74.03%  notVegetation
# 627   8783.png  notVegetation      2.08%        97.92%  notVegetation
# 628   8802.png  notVegetation     21.33%        78.67%  notVegetation
# 629   8812.png  notVegetation      1.51%        98.49%  notVegetation
# 630   8821.png  notVegetation      4.67%        95.33%  notVegetation
# 631   8838.png  notVegetation      2.60%        97.40%  notVegetation
# 632   8853.png  notVegetation     19.45%        80.55%  notVegetation
# 633   8856.png  notVegetation      3.64%        96.36%  notVegetation
# 634   8860.png  notVegetation     23.95%        76.05%  notVegetation
# 635   8872.png  notVegetation      5.28%        94.72%  notVegetation
# 636   8914.png  notVegetation     13.81%        86.19%  notVegetation
# 637   8931.png  notVegetation      0.57%        99.43%  notVegetation
# 638   8932.png  notVegetation     45.50%        54.50%  notVegetation
# 639   9029.png  notVegetation      4.91%        95.09%  notVegetation
# 640   9033.png  notVegetation      8.79%        91.21%  notVegetation
# 641   9058.png  notVegetation     20.27%        79.73%  notVegetation
# 642   9072.png  notVegetation     12.47%        87.53%  notVegetation
# 643   9116.png  notVegetation     10.29%        89.71%  notVegetation
# 644   9181.png  notVegetation     16.15%        83.85%  notVegetation
# 645   9218.png  notVegetation      0.70%        99.30%  notVegetation
# 646   9255.png  notVegetation      1.05%        98.95%  notVegetation
# 647   9294.png  notVegetation     31.05%        68.95%  notVegetation
# 648   9306.png  notVegetation      0.43%        99.57%  notVegetation
# 649   9422.png  notVegetation     29.71%        70.29%  notVegetation
# 650     97.png  notVegetation      4.19%        95.81%  notVegetation
# 651   9713.png  notVegetation     23.83%        76.17%  notVegetation
# 652   9792.png  notVegetation     17.74%        82.26%  notVegetation
# 653   9971.png  notVegetation      6.50%        93.50%  notVegetation
# 654   9983.png  notVegetation      7.13%        92.87%  notVegetation
#
# [655 rows x 5 columns]
# ===== Confusion Matrix ======
# [[342  20]
#  [ 25 268]]
# Accuracy of Test Images : 93.13%

# %%
session.close()
